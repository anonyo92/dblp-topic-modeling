# %% [markdown]
# ## General Utilities

# %%
import numpy as np
import pandas as pd
import csv
import json

# %%
def print_first_n_dict_items(d: dict, dict_name: str, n: int):
    print("\nPrinting first", n, "items of dict named", dict_name, "\n========================================================")
    i = 0
    for key, value in d.items():
        print(key, ":", value)
        i += 1
        if i == n:
            break

# %%
def print_document_word_scores(document, doc_word_dict, mode):
    if mode == 'BOW':
        for i in range(len(document)):
            print("Word {} (\"{}\") appears {} time.".format(document[i][0], doc_word_dict[document[i][0]], document[i][1]))
    elif mode == 'TF_IDF':
        for i in range(len(document)):
            print("Word {} (\"{}\")'s TF-IDF is {}.".format(document[i][0], doc_word_dict[document[i][0]], document[i][1]))

# %%
def print_topics_from_model(model):
    for idx, topic in model.print_topics(-1):
        print('Topic: {} \nWords: {}'.format(idx, topic))

# %% [markdown]
# ## Load Data

# %%
f = open("./data/titles_lemmatized.json","r")
title_orig_lemmatized_map = json.load(f)
f.close()

# %%
type(title_orig_lemmatized_map)
len(title_orig_lemmatized_map)
# Out:
# 1952578

# %%
f = open("./data/keyword_counts.json","r")
keyword_counts_raw = json.load(f)
f.close()

# %%
type(keyword_counts_raw)
len(keyword_counts_raw)
# Out:
# 448770

# %%
print_first_n_dict_items(keyword_counts_raw, "Keyword-counts", 10)
# Out:
# Printing first 10 items of dict named Keyword-counts
# ========================================================
# system : 191799
# network : 166093
# model : 111842
# analysis : 101884
# algorithm : 97362
# data : 83604
# method : 81866
# approach : 73121
# problem : 66562
# application : 66391

# %%
print_first_n_dict_items(title_orig_lemmatized_map, "Titles: Original-Lemmatized Map", 10)
# Out:
# Printing first 10 items of dict named Titles: Original-Lemmatized Map
# ========================================================
# Parallel Integer Sorting and Simulation Amongst CRCW Models : ['parallel', 'integer', 'sorting', 'simulation', 'crcw', 'model']
# Pattern Matching in Trees and Nets : ['pattern', 'matching', 'tree', 'net']
# NP-complete Problems Simplified on Tree Schemas : ['np-complete', 'problem', 'simplified', 'tree', 'schema']
# On the Power of Chain Rules in Context Free Grammars : ['power', 'chain', 'rule', 'context', 'free', 'grammar']
# Schnelle Multiplikation von Polynomen über Körpern der Charakteristik 2 : ['schnelle', 'multiplikation', 'von', 'polynomen', 'über', 'körpern', 'der', 'charakteristik', '2']
# A characterization of rational D0L power series : ['characterization', 'rational', 'd0l', 'power', 'series']
# The Derivation of Systolic Implementations of Programs : ['derivation', 'systolic', 'implementation', 'program']
# Fifo Nets Without Order Deadlock : ['fifo', 'net', 'order', 'deadlock']
# On the Complementation Rule for Multivalued Dependencies in Database Relations : ['complementation', 'rule', 'multivalued', 'dependency', 'database', 'relation']
# Equational weighted tree transformations : ['equational', 'weighted', 'tree', 'transformation']

# %%
title_lemma = list(title_orig_lemmatized_map.values())
title_lemma[:10]
# Out:
# [['parallel', 'integer', 'sorting', 'simulation', 'crcw', 'model'],
#  ['pattern', 'matching', 'tree', 'net'],
#  ['np-complete', 'problem', 'simplified', 'tree', 'schema'],
#  ['power', 'chain', 'rule', 'context', 'free', 'grammar'],
#  ['schnelle',
#   'multiplikation',
#   'von',
#   'polynomen',
#   'über',
#   'körpern',
#   'der',
#   'charakteristik',
#   '2'],
#  ['characterization', 'rational', 'd0l', 'power', 'series'],
#  ['derivation', 'systolic', 'implementation', 'program'],
#  ['fifo', 'net', 'order', 'deadlock'],
#  ['complementation',
#   'rule',
#   'multivalued',
#   'dependency',
#   'database',
#   'relation'],
#  ['equational', 'weighted', 'tree', 'transformation']]

# %% [markdown]
# ### Random checks

# %%
i = 0
for orig_title, lemmatized_title in title_orig_lemmatized_map.items():
    if 'de' in lemmatized_title:
        print(orig_title)
        i += 1
    if i == 10:
        break

# %% [markdown]
# ## Bag-of-Words (BOW)

# %%
import gensim
from gensim import corpora, models

# %%
title_lemma_dict = gensim.corpora.Dictionary(title_lemma)

# %%
count = 0
for k, v in title_lemma_dict.iteritems():
    print(k, v)
    count += 1
    if count > 15:
        break
# Out:
# 0 crcw
# 1 integer
# 2 model
# 3 parallel
# 4 simulation
# 5 sorting
# 6 matching
# 7 net
# 8 pattern
# 9 tree
# 10 np-complete
# 11 problem
# 12 schema
# 13 simplified
# 14 chain
# 15 context

# %% [markdown]
# ### Filter extremes - Filter tokens that appear in:
# 1. fewer than 15 documents (absolute number) or,
# 2. more than 0.5 documents (fraction of total corpus size, not absolute number).
# 3. After the above two steps, keep only the first 100000 most frequent tokens.

# %%
title_lemma_dict.filter_extremes(no_below=15, no_above=0.5, keep_n=100000)

# %%
len(title_lemma_dict)
# Out:
# 31010

# %% [markdown]
# ### Doc2BOW

# %%
bow_corpus = [title_lemma_dict.doc2bow(lemmatized_title_word) for lemmatized_title_word in title_lemma]

# %%
bow_corpus[4310]
# Out:
# [(67, 1),
#  (260, 1),
#  (282, 1),
#  (296, 1),
#  (1741, 1),
#  (2060, 1),
#  (3143, 1),
#  (4115, 1)]

# %%
len(bow_corpus)
# Out:
# 1952578

# %%
print_document_word_scores(bow_corpus[4310], title_lemma_dict, mode='BOW')
# Out:
# Word 67 ("algorithm") appears 1 time.
# Word 260 ("execution") appears 1 time.
# Word 282 ("composite") appears 1 time.
# Word 296 ("service") appears 1 time.
# Word 1741 ("partitioning") appears 1 time.
# Word 2060 ("web") appears 1 time.
# Word 3143 ("genetic") appears 1 time.
# Word 4115 ("decentralized") appears 1 time.

# %% [markdown]
# ## TF-IDF

# %%
tfidf = models.TfidfModel(bow_corpus)
corpus_tfidf = tfidf[bow_corpus]

# %%
len(corpus_tfidf)
type(corpus_tfidf)
# Out:
# gensim.interfaces.TransformedCorpus

# %%
from pprint import pprint

# %%
for doc in corpus_tfidf[:3]:
    pprint(doc)
    #break
# Out:
# [(0, 0.5308074793145152),
#  (1, 0.2462960348359242),
#  (2, 0.3895247938433522),
#  (3, 0.3755981642789065),
#  (4, 0.6039686557260081)]
# [(5, 0.5067294312228873),
#  (6, 0.5737547463930259),
#  (7, 0.450967134840957),
#  (8, 0.4589764893949818)]
# [(8, 0.32738298819751377),
#  (9, 0.59199325173433),
#  (10, 0.23170406395473353),
#  (11, 0.49497688257556743),
#  (12, 0.4936349677671899)]

# %%
print_document_word_scores(corpus_tfidf[4310], title_lemma_dict, mode='TF_IDF')
# Out:
# Word 67 ("algorithm")'s TF-IDF is 0.1916219769949481.
# Word 260 ("execution")'s TF-IDF is 0.42409763898777847.
# Word 282 ("composite")'s TF-IDF is 0.4173157286634347.
# Word 296 ("service")'s TF-IDF is 0.27425479081388066.
# Word 1741 ("partitioning")'s TF-IDF is 0.40872772221798553.
# Word 2060 ("web")'s TF-IDF is 0.2978792503904838.
# Word 3143 ("genetic")'s TF-IDF is 0.33236993722554525.
# Word 4115 ("decentralized")'s TF-IDF is 0.40962657258687246.

# %% [markdown]
# ## LDA on BOW

# %%
lda_model_bow = gensim.models.LdaMulticore(bow_corpus, id2word=title_lemma_dict, num_topics=10, passes=2, workers=2)

# %%
print_topics_from_model(lda_model_bow)
# Out:
# Topic: 0
# Words: 0.060*"graph" + 0.022*"set" + 0.021*"recognition" + 0.016*"function" + 0.015*"space" + 0.014*"number" + 0.012*"pattern" + 0.010*"algorithm" + 0.009*"theorem" + 0.009*"group"
# Topic: 1
# Words: 0.055*"network" + 0.025*"system" + 0.020*"wireless" + 0.020*"sensor" + 0.017*"scheme" + 0.015*"based" + 0.014*"channel" + 0.014*"communication" + 0.013*"performance" + 0.013*"power"
# Topic: 2
# Words: 0.047*"image" + 0.021*"based" + 0.021*"classification" + 0.019*"feature" + 0.016*"selection" + 0.014*"method" + 0.013*"automatic" + 0.012*"point" + 0.011*"3d" + 0.011*"detection"
# Topic: 3
# Words: 0.020*"system" + 0.017*"design" + 0.017*"issue" + 0.016*"special" + 0.015*"test" + 0.013*"analysis" + 0.013*"computer" + 0.012*"noise" + 0.012*"measurement" + 0.011*"simulation"
# Topic: 4
# Words: 0.062*"system" + 0.038*"control" + 0.021*"nonlinear" + 0.020*"linear" + 0.019*"method" + 0.017*"solution" + 0.017*"class" + 0.013*"equation" + 0.013*"problem" + 0.013*"order"
# Topic: 5
# Words: 0.049*"algorithm" + 0.036*"problem" + 0.030*"optimization" + 0.024*"network" + 0.022*"time" + 0.019*"model" + 0.018*"robot" + 0.017*"dynamic" + 0.015*"neural" + 0.012*"approach"
# Topic: 6
# Words: 0.023*"code" + 0.019*"algorithm" + 0.019*"tree" + 0.016*"search" + 0.016*"complexity" + 0.014*"machine" + 0.014*"random" + 0.013*"property" + 0.012*"polynomial" + 0.012*"vector"
# Topic: 7
# Words: 0.030*"learning" + 0.019*"service" + 0.018*"system" + 0.017*"environment" + 0.016*"mobile" + 0.015*"virtual" + 0.013*"network" + 0.012*"user" + 0.012*"game" + 0.011*"web"
# Topic: 8
# Words: 0.044*"system" + 0.037*"data" + 0.020*"analysis" + 0.020*"software" + 0.018*"model" + 0.017*"approach" + 0.016*"process" + 0.015*"distributed" + 0.012*"design" + 0.012*"language"
# Topic: 9
# Words: 0.031*"study" + 0.019*"information" + 0.016*"technology" + 0.016*"case" + 0.016*"research" + 0.011*"use" + 0.010*"social" + 0.009*"review" + 0.009*"science" + 0.009*"impact"

# %% [markdown]
# ## LDA on TF-IDF

# %%
lda_model_tfidf = gensim.models.LdaMulticore(corpus_tfidf, id2word=title_lemma_dict, num_topics=8, passes=2, workers=4)

# %%
print_topics_from_model(lda_model_tfidf)
# Out:
# Topic: 0
# Words: 0.014*"network" + 0.011*"wireless" + 0.011*"system" + 0.008*"channel" + 0.007*"communication" + 0.007*"sensor" + 0.007*"performance" + 0.006*"power" + 0.005*"und" + 0.005*"radio"
# Topic: 1
# Words: 0.009*"system" + 0.008*"model" + 0.008*"polynomial" + 0.006*"control" + 0.006*"analysis" + 0.005*"time" + 0.005*"nonlinear" + 0.005*"estimation" + 0.005*"algorithm" + 0.005*"delay"
# Topic: 2
# Words: 0.013*"image" + 0.006*"segmentation" + 0.005*"based" + 0.005*"feature" + 0.005*"retrieval" + 0.005*"shape" + 0.004*"object" + 0.004*"data" + 0.004*"code" + 0.004*"classification"
# Topic: 3
# Words: 0.010*"algorithm" + 0.008*"network" + 0.007*"optimization" + 0.007*"problem" + 0.006*"routing" + 0.005*"system" + 0.005*"based" + 0.005*"control" + 0.004*"vehicle" + 0.004*"swarm"
# Topic: 4
# Words: 0.009*"recognition" + 0.008*"robot" + 0.007*"neural" + 0.007*"learning" + 0.006*"human" + 0.006*"special" + 0.006*"system" + 0.006*"detection" + 0.006*"brain" + 0.006*"based"
# Topic: 5
# Words: 0.008*"system" + 0.008*"information" + 0.008*"software" + 0.006*"research" + 0.006*"study" + 0.006*"technology" + 0.006*"management" + 0.006*"social" + 0.006*"development" + 0.005*"knowledge"
# Topic: 6
# Words: 0.018*"graph" + 0.009*"set" + 0.007*"logic" + 0.007*"number" + 0.006*"tree" + 0.005*"algorithm" + 0.005*"theorem" + 0.005*"cycle" + 0.005*"problem" + 0.005*"complexity"
# Topic: 7
# Words: 0.010*"problem" + 0.009*"graph" + 0.008*"equation" + 0.008*"method" + 0.006*"algorithm" + 0.006*"solution" + 0.005*"matrix" + 0.005*"finite" + 0.005*"mimo" + 0.005*"linear"

# %% [markdown]
# ## Performance Evaluation

# %%
def generate_topic_prediction_scores(document, model):
    for index, score in sorted(model[document], key=lambda tup: -1*tup[1]):
        print("\nScore: {}\t \nTopic: {}".format(score, model.print_topic(index, 10)))

# %% [markdown]
# ### 1. LDA(BOW)

# %%
random_doc_id = 4310
title_lemma[random_doc_id]
#print_document_word_counts(bow_corpus[4310], title_lemma_dict, mode='BOW')
# Out:
# ['partitioning',
#  'composite',
#  'web',
#  'service',
#  'decentralized',
#  'execution',
#  'genetic',
#  'algorithm']

# %%
lda_model_bow[bow_corpus[random_doc_id]]
# Out:
# [(13, 0.1122162),
#  (16, 0.11222506),
#  (18, 0.11222527),
#  (35, 0.11221849),
#  (39, 0.11222506),
#  (40, 0.11222008),
#  (76, 0.11222123),
#  (81, 0.112223156)]

# %%
generate_topic_prediction_scores(bow_corpus[random_doc_id], lda_model_bow)
# Out:
# Score: 0.11222528666257858
# Topic: 0.383*"algorithm" + 0.235*"problem" + 0.121*"efficient" + 0.046*"spatial" + 0.037*"solving" + 0.033*"simple" + 0.030*"minimum" + 0.027*"temporal" + 0.009*"searching" + 0.009*"reflection"
#
# Score: 0.11222506314516068
# Topic: 0.273*"service" + 0.062*"training" + 0.048*"receiver" + 0.047*"variation" + 0.043*"recovery" + 0.038*"variational" + 0.035*"maintenance" + 0.035*"estimate" + 0.033*"loop" + 0.032*"controlled"
#
# Score: 0.11222506314516068
# Topic: 0.269*"web" + 0.051*"formula" + 0.051*"site" + 0.050*"attribute" + 0.047*"usability" + 0.046*"price" + 0.036*"limited" + 0.033*"consideration" + 0.024*"company" + 0.024*"application"
#
# Score: 0.11222314089536667
# Topic: 0.248*"detection" + 0.116*"novel" + 0.097*"complex" + 0.075*"genetic" + 0.070*"interactive" + 0.042*"system" + 0.041*"based" + 0.037*"operator" + 0.034*"convergence" + 0.032*"approach"
#
# Score: 0.11222121864557266
# Topic: 0.263*"test" + 0.103*"series" + 0.093*"ii" + 0.071*"simultaneous" + 0.070*"growth" + 0.046*"module" + 0.043*"execution" + 0.034*"workflow" + 0.025*"model" + 0.021*"derived"
#
# Score: 0.11222009360790253
# Topic: 0.190*"distribution" + 0.093*"influence" + 0.088*"community" + 0.067*"perception" + 0.052*"integral" + 0.044*"switched" + 0.043*"determination" + 0.035*"composite" + 0.026*"extreme" + 0.023*"perceived"
#
# Score: 0.112218476831913
# Topic: 0.166*"stability" + 0.114*"general" + 0.095*"active" + 0.084*"word" + 0.058*"motor" + 0.054*"system" + 0.034*"agent-based" + 0.033*"connection" + 0.032*"model" + 0.029*"synchronous"
#
# Score: 0.11221619695425034
# Topic: 0.129*"simulation" + 0.106*"virtual" + 0.085*"flow" + 0.069*"internet" + 0.056*"device" + 0.045*"challenge" + 0.043*"policy" + 0.042*"different" + 0.040*"degree" + 0.036*"location"

# %% [markdown]
# ### 2. LDA (TF-IDF)

# %%
print_document_word_counts(corpus_tfidf[4310], title_lemma_dict, mode='TF_IDF')
# Out:
# Word 67 ("algorithm")'s TF-IDF is 0.1916219769949481.
# Word 261 ("execution")'s TF-IDF is 0.42409763898777847.
# Word 283 ("composite")'s TF-IDF is 0.4173157286634347.
# Word 297 ("service")'s TF-IDF is 0.27425479081388066.
# Word 1742 ("partitioning")'s TF-IDF is 0.40872772221798553.
# Word 2061 ("web")'s TF-IDF is 0.2978792503904838.
# Word 3144 ("genetic")'s TF-IDF is 0.33236993722554525.
# Word 4116 ("decentralized")'s TF-IDF is 0.40962657258687246.

# %%
lda_model_tfidf[corpus_tfidf[random_doc_id]]
# Out:
# [(0, 0.7662858),
#  (1, 0.03337222),
#  (2, 0.033349838),
#  (3, 0.03349388),
#  (4, 0.033338945),
#  (5, 0.033419743),
#  (6, 0.03340059),
#  (7, 0.033338983)]

# %%
generate_topic_prediction_scores(corpus_tfidf[random_doc_id], lda_model_tfidf)
# Out:
# Score: 0.7662761211395264
# Topic: 0.014*"network" + 0.011*"wireless" + 0.011*"system" + 0.008*"channel" + 0.007*"communication" + 0.007*"sensor" + 0.007*"performance" + 0.006*"power" + 0.005*"und" + 0.005*"radio"
#
# Score: 0.03350401297211647
# Topic: 0.010*"algorithm" + 0.008*"network" + 0.007*"optimization" + 0.007*"problem" + 0.006*"routing" + 0.005*"system" + 0.005*"based" + 0.005*"control" + 0.004*"vehicle" + 0.004*"swarm"
#
# Score: 0.03341921046376228
# Topic: 0.008*"system" + 0.008*"information" + 0.008*"software" + 0.006*"research" + 0.006*"study" + 0.006*"technology" + 0.006*"management" + 0.006*"social" + 0.006*"development" + 0.005*"knowledge"
#
# Score: 0.03340056911110878
# Topic: 0.018*"graph" + 0.009*"set" + 0.007*"logic" + 0.007*"number" + 0.006*"tree" + 0.005*"algorithm" + 0.005*"theorem" + 0.005*"cycle" + 0.005*"problem" + 0.005*"complexity"
#
# Score: 0.033372242003679276
# Topic: 0.009*"system" + 0.008*"model" + 0.008*"polynomial" + 0.006*"control" + 0.006*"analysis" + 0.005*"time" + 0.005*"nonlinear" + 0.005*"estimation" + 0.005*"algorithm" + 0.005*"delay"
#
# Score: 0.03334985300898552
# Topic: 0.013*"image" + 0.006*"segmentation" + 0.005*"based" + 0.005*"feature" + 0.005*"retrieval" + 0.005*"shape" + 0.004*"object" + 0.004*"data" + 0.004*"code" + 0.004*"classification"
#
# Score: 0.0333389975130558
# Topic: 0.010*"problem" + 0.009*"graph" + 0.008*"equation" + 0.008*"method" + 0.006*"algorithm" + 0.006*"solution" + 0.005*"matrix" + 0.005*"finite" + 0.005*"mimo" + 0.005*"linear"
#
# Score: 0.03333896026015282
# Topic: 0.009*"recognition" + 0.008*"robot" + 0.007*"neural" + 0.007*"learning" + 0.006*"human" + 0.006*"special" + 0.006*"system" + 0.006*"detection" + 0.006*"brain" + 0.006*"based"

# %% [markdown]
# ## Test Predictions on unseen document

# %%
# test_title = 'TensorFlow - A system for large-scale machine learning'
# test_title_lemma = ['TensorFlow', 'system', 'large', 'scale', 'machine', 'learning']

test_title = 'An efficient algorithm to improve CPU cache hit-rate in x86 architectures'
test_title_lemma = ['efficient', 'algorithm', 'improve', 'CPU', 'cache', 'hit-rate', 'x86', 'architecture']

# %%
test_title_lemma_dict = gensim.corpora.Dictionary([test_title_lemma])
test_bow_vector = test_title_lemma_dict.doc2bow(test_title_lemma)

# %% [markdown]
# ### 1. LDA(BOW) Test

# %%
lda_model_bow.get_document_topics(test_bow_vector)
# Out:
# [(0, 0.19466658),
#  (1, 0.011112118),
#  (2, 0.011115115),
#  (3, 0.011116207),
#  (4, 0.0111123705),
#  (5, 0.533563),
#  (6, 0.1939754),
#  (7, 0.011112384),
#  (8, 0.011114642),
#  (9, 0.011112221)]

# %%
generate_topic_prediction_scores(test_bow_vector, lda_model_bow)
# Out:
# Score: 0.533555805683136
# Topic: 0.049*"algorithm" + 0.036*"problem" + 0.030*"optimization" + 0.024*"network" + 0.022*"time" + 0.019*"model" + 0.018*"robot" + 0.017*"dynamic" + 0.015*"neural" + 0.012*"approach"
#
# Score: 0.19465483725070953
# Topic: 0.060*"graph" + 0.022*"set" + 0.021*"recognition" + 0.016*"function" + 0.015*"space" + 0.014*"number" + 0.012*"pattern" + 0.010*"algorithm" + 0.009*"theorem" + 0.009*"group"
#
# Score: 0.19399428367614746
# Topic: 0.023*"code" + 0.019*"algorithm" + 0.019*"tree" + 0.016*"search" + 0.016*"complexity" + 0.014*"machine" + 0.014*"random" + 0.013*"property" + 0.012*"polynomial" + 0.012*"vector"
#
# Score: 0.011116203851997852
# Topic: 0.020*"system" + 0.017*"design" + 0.017*"issue" + 0.016*"special" + 0.015*"test" + 0.013*"analysis" + 0.013*"computer" + 0.012*"noise" + 0.012*"measurement" + 0.011*"simulation"
#
# Score: 0.011115114204585552
# Topic: 0.047*"image" + 0.021*"based" + 0.021*"classification" + 0.019*"feature" + 0.016*"selection" + 0.014*"method" + 0.013*"automatic" + 0.012*"point" + 0.011*"3d" + 0.011*"detection"
#
# Score: 0.011114641092717648
# Topic: 0.044*"system" + 0.037*"data" + 0.020*"analysis" + 0.020*"software" + 0.018*"model" + 0.017*"approach" + 0.016*"process" + 0.015*"distributed" + 0.012*"design" + 0.012*"language"
#
# Score: 0.011112382635474205
# Topic: 0.030*"learning" + 0.019*"service" + 0.018*"system" + 0.017*"environment" + 0.016*"mobile" + 0.015*"virtual" + 0.013*"network" + 0.012*"user" + 0.012*"game" + 0.011*"web"
#
# Score: 0.01111236959695816
# Topic: 0.062*"system" + 0.038*"control" + 0.021*"nonlinear" + 0.020*"linear" + 0.019*"method" + 0.017*"solution" + 0.017*"class" + 0.013*"equation" + 0.013*"problem" + 0.013*"order"
#
# Score: 0.011112219654023647
# Topic: 0.031*"study" + 0.019*"information" + 0.016*"technology" + 0.016*"case" + 0.016*"research" + 0.011*"use" + 0.010*"social" + 0.009*"review" + 0.009*"science" + 0.009*"impact"
#
# Score: 0.01111211720854044
# Topic: 0.055*"network" + 0.025*"system" + 0.020*"wireless" + 0.020*"sensor" + 0.017*"scheme" + 0.015*"based" + 0.014*"channel" + 0.014*"communication" + 0.013*"performance" + 0.013*"power"

# %% [markdown]
# ### 2. LDA(TF-IDF) Test

# %%
generate_topic_prediction_scores(test_bow_vector, lda_model_tfidf)
# Out:
# Score: 0.8747457265853882
# Topic: 0.018*"graph" + 0.009*"set" + 0.007*"logic" + 0.007*"number" + 0.006*"tree" + 0.005*"algorithm" + 0.005*"theorem" + 0.005*"cycle" + 0.005*"problem" + 0.005*"complexity"
#
# Score: 0.0179138220846653
# Topic: 0.009*"recognition" + 0.008*"robot" + 0.007*"neural" + 0.007*"learning" + 0.006*"human" + 0.006*"special" + 0.006*"system" + 0.006*"detection" + 0.006*"brain" + 0.006*"based"
#
# Score: 0.017906084656715393
# Topic: 0.010*"algorithm" + 0.008*"network" + 0.007*"optimization" + 0.007*"problem" + 0.006*"routing" + 0.005*"system" + 0.005*"based" + 0.005*"control" + 0.004*"vehicle" + 0.004*"swarm"
#
# Score: 0.017888925969600677
# Topic: 0.014*"network" + 0.011*"wireless" + 0.011*"system" + 0.008*"channel" + 0.007*"communication" + 0.007*"sensor" + 0.007*"performance" + 0.006*"power" + 0.005*"und" + 0.005*"radio"
#
# Score: 0.017888149246573448
# Topic: 0.008*"system" + 0.008*"information" + 0.008*"software" + 0.006*"research" + 0.006*"study" + 0.006*"technology" + 0.006*"management" + 0.006*"social" + 0.006*"development" + 0.005*"knowledge"
#
# Score: 0.017888061702251434
# Topic: 0.010*"problem" + 0.009*"graph" + 0.008*"equation" + 0.008*"method" + 0.006*"algorithm" + 0.006*"solution" + 0.005*"matrix" + 0.005*"finite" + 0.005*"mimo" + 0.005*"linear"
#
# Score: 0.017887866124510765
# Topic: 0.009*"system" + 0.008*"model" + 0.008*"polynomial" + 0.006*"control" + 0.006*"analysis" + 0.005*"time" + 0.005*"nonlinear" + 0.005*"estimation" + 0.005*"algorithm" + 0.005*"delay"
#
# Score: 0.017881348729133606
# Topic: 0.013*"image" + 0.006*"segmentation" + 0.005*"based" + 0.005*"feature" + 0.005*"retrieval" + 0.005*"shape" + 0.004*"object" + 0.004*"data" + 0.004*"code" + 0.004*"classification"

# %% [markdown]
# ## Generate topics for top keywords

# %%
lda_model_bow = models.LdaModel.load('./model/lda_bow.model', mmap='r')

# %%
# Sort as it is a dict() and order need not have been preserved
keyword_counts = sorted(keyword_counts_raw.items(), key = lambda kv:(kv[1], kv[0]), reverse=True)
keyword_counts
# Out:
# [('system', 191799),
#  ('network', 166093),
#  ('model', 111842),
#  ('analysis', 101884),
#  ('algorithm', 97362),
#  ('data', 83604),
#  ('method', 81866),
#  ('approach', 73121),
#  ('problem', 66562),
#  ('application', 66391),
#  ('control', 65290),
#  ('learning', 60695),
#  ('design', 60176),
#  ('image', 55137),
#  ('information', 53651),
#  ('dynamic', 45930),
#  ('graph', 45692),
#  ('detection', 42851),
#  ('study', 41767),
#  ('new', 41368),
#  ('performance', 40169),
#  ('optimization', 37933),
#  ('wireless', 36651),
#  ('neural', 36613),
#  ('estimation', 34629),
#  ('adaptive', 34213),
#  ('efficient', 33874),
#  ('fuzzy', 33855),
#  ('sensor', 31748),
#  ('linear', 31313),
#  ('modeling', 31255),
#  ('function', 31018),
#  ('scheme', 29853),
#  ('optimal', 29646),
#  ('mobile', 29518),
#  ('management', 29274),
#  ('distributed', 29161),
#  ('time', 29007),
#  ('communication', 28883),
#  ('channel', 28602),
#  ('process', 28520),
#  ('equation', 27539),
#  ('service', 27432),
#  ('framework', 26778),
#  ('power', 26750),
#  ('classification', 26229),
#  ('evaluation', 26021),
#  ('set', 25379),
#  ('structure', 25337),
#  ('software', 25309),
#  ('technique', 24998),
#  ('simulation', 24690),
#  ('code', 24690),
#  ('multiple', 24504),
#  ('environment', 24432),
#  ('computing', 23788),
#  ('recognition', 23715),
#  ('solution', 22957),
#  ('robust', 22704),
#  ('nonlinear', 22659),
#  ('effect', 22651),
#  ('theory', 22318),
#  ('machine', 22275),
#  ('feature', 22086),
#  ('case', 21207),
#  ('technology', 21194),
#  ('social', 21178),
#  ('parallel', 20838),
#  ('development', 20783),
#  ('architecture', 20696),
#  ('scheduling', 20594),
#  ('selection', 20380),
#  ('hybrid', 20072),
#  ('programming', 19643),
#  ('digital', 19292),
#  ('decision', 19256),
#  ('space', 19080),
#  ('signal', 19005),
#  ('web', 18720),
#  ('search', 18520),
#  ('protocol', 18509),
#  ('novel', 18507),
#  ('prediction', 18353),
#  ('online', 18304),
#  ('logic', 18275),
#  ('knowledge', 18221),
#  ('energy', 18175),
#  ('language', 18119),
#  ('fast', 18103),
#  ('research', 18065),
#  ('video', 18057),
#  ('strategy', 17966),
#  ('computer', 17862),
#  ('pattern', 17681),
#  ('matrix', 17669),
#  ('support', 17666),
#  ('review', 17593),
#  ('stochastic', 17582),
#  ('random', 17105),
#  ('implementation', 17052),
#  ('game', 16805),
#  ('number', 16702),
#  ('robot', 16687),
#  ('tree', 16598),
#  ('distribution', 16567),
#  ('processing', 16557),
#  ('flow', 16531),
#  ('user', 16204),
#  ('error', 16012),
#  ('generalized', 15989),
#  ('sequence', 15951),
#  ('human', 15896),
#  ('representation', 15821),
#  ('security', 15610),
#  ('object', 15581),
#  ('finite', 15569),
#  ('complexity', 15443),
#  ('class', 15348),
#  ('resource', 15282),
#  ('constraint', 15245),
#  ('group', 15195),
#  ('issue', 14971),
#  ('state', 14916),
#  ('database', 14896),
#  ('virtual', 14868),
#  ('tool', 14834),
#  ('use', 14692),
#  ('routing', 14576),
#  ('bound', 14536),
#  ('local', 14419),
#  ('clustering', 14355),
#  ('identification', 14345),
#  ('approximation', 14262),
#  ('measurement', 14196),
#  ('automatic', 14193),
#  ('property', 14115),
#  ('improved', 14108),
#  ('field', 14046),
#  ('real-time', 14038),
#  ('generation', 13921),
#  ('quality', 13850),
#  ('access', 13824),
#  ('tracking', 13811),
#  ('interaction', 13768),
#  ('filter', 13705),
#  ('program', 13565),
#  ('cloud', 13483),
#  ('comparison', 13439),
#  ('3d', 13415),
#  ('internet', 13405),
#  ('deep', 13400),
#  ('coding', 13378),
#  ('high', 13269),
#  ('complex', 13256),
#  ('surface', 13231),
#  ('visual', 13217),
#  ('point', 13209),
#  ('parameter', 13205),
#  ('delay', 13119),
#  ('stability', 13096),
#  ('editorial', 13064),
#  ('impact', 12842),
#  ('allocation', 12812),
#  ('computation', 12763),
#  ('global', 12723),
#  ('large', 12722),
#  ('segmentation', 12721),
#  ('vector', 12364),
#  ('differential', 12179),
#  ('source', 12136),
#  ('special', 12102),
#  ('cognitive', 12079),
#  ('memory', 12040),
#  ('order', 12026),
#  ('rate', 11945),
#  ('product', 11878),
#  ('motion', 11874),
#  ('assessment', 11847),
#  ('sensing', 11785),
#  ('spatial', 11779),
#  ('computational', 11679),
#  ('planning', 11603),
#  ('survey', 11600),
#  ('polynomial', 11587),
#  ('domain', 11553),
#  ('retrieval', 11439),
#  ('path', 11401),
#  ('test', 11252),
#  ('engineering', 11153),
#  ('circuit', 11123),
#  ('integrated', 11022),
#  ('noise', 11007),
#  ('sparse', 10962),
#  ('feedback', 10961),
#  ('solving', 10884),
#  ('mapping', 10820),
#  ('monitoring', 10733),
#  ('mechanism', 10733),
#  ('reduction', 10672),
#  ('genetic', 10563),
#  ('modelling', 10540),
#  ('value', 10511),
#  ('behavior', 10481),
#  ('perspective', 10453),
#  ('discrete', 10452),
#  ('mining', 10369),
#  ('type', 10328),
#  ('frequency', 10298),
#  ('vehicle', 10273),
#  ('note', 10259),
#  ('joint', 10256),
#  ('mimo', 10220),
#  ('semantic', 10176),
#  ('transmission', 10172),
#  ('quantum', 10161),
#  ('numerical', 10134),
#  ('condition', 10114),
#  ('decomposition', 10108),
#  ('heterogeneous', 10100),
#  ('construction', 10082),
#  ('map', 9990),
#  ('measure', 9913),
#  ('traffic', 9907),
#  ('matching', 9882),
#  ('variable', 9842),
#  ('grid', 9770),
#  ('secure', 9708),
#  ('optical', 9691),
#  ('medium', 9658),
#  ('bayesian', 9626),
#  ('statistical', 9587),
#  ('fault', 9580),
#  ('general', 9570),
#  ('science', 9547),
#  ('radio', 9540),
#  ('smart', 9527),
#  ('introduction', 9505),
#  ('testing', 9496),
#  ('functional', 9479),
#  ('device', 9474),
#  ('integration', 9413),
#  ('improving', 9386),
#  ('cooperative', 9372),
#  ('result', 9345),
#  ('hierarchical', 9337),
#  ('rule', 9171),
#  ('chain', 9092),
#  ('factor', 9084),
#  ('extraction', 9060),
#  ('interface', 9050),
#  ('intelligent', 9005),
#  ('reconstruction', 8991),
#  ('distance', 8931),
#  ('task', 8926),
#  ('binary', 8861),
#  ('cellular', 8860),
#  ('probabilistic', 8813),
#  ('spectrum', 8784),
#  ('response', 8776),
#  ('change', 8751),
#  ('theorem', 8694),
#  ('role', 8694),
#  ('automated', 8651),
#  ('interactive', 8623),
#  ('policy', 8621),
#  ('challenge', 8621),
#  ('simple', 8619),
#  ('speech', 8580),
#  ('protein', 8534),
#  ('evolution', 8492),
#  ('element', 8473),
#  ('cell', 8434),
#  ('activity', 8427),
#  ('cost', 8421),
#  ('array', 8420),
#  ('risk', 8417),
#  ('query', 8399),
#  ('boundary', 8348),
#  ('characterization', 8296),
#  ('uncertainty', 8294),
#  ('empirical', 8269),
#  ('low', 8231),
#  ('electronic', 8211),
#  ('key', 8147),
#  ('artificial', 8138),
#  ('attack', 8094),
#  ('gene', 8081),
#  ('active', 8077),
#  ('imaging', 8074),
#  ('component', 8065),
#  ('capacity', 7986),
#  ('interference', 7977),
#  ('maximum', 7895),
#  ('library', 7871),
#  ('project', 7804),
#  ('convergence', 7801),
#  ('single', 7783),
#  ('line', 7748),
#  ('regression', 7717),
#  ('collaborative', 7685),
#  ('level', 7666),
#  ('partial', 7658),
#  ('synthesis', 7645),
#  ('controller', 7615),
#  ('open', 7600),
#  ('index', 7587),
#  ('spectral', 7559),
#  ('continuous', 7541),
#  ('weighted', 7528),
#  ('shape', 7511),
#  ('operation', 7502),
#  ('agent', 7500),
#  ('small', 7489),
#  ('efficiency', 7477),
#  ('localization', 7467),
#  ('sharing', 7463),
#  ('text', 7461),
#  ('platform', 7456),
#  ('minimum', 7453),
#  ('iterative', 7408),
#  ('community', 7398),
#  ('transfer', 7393),
#  ('reliability', 7358),
#  ('large-scale', 7353),
#  ('filtering', 7349),
#  ('phase', 7328),
#  ('business', 7265),
#  ('operator', 7257),
#  ('temporal', 7250),
#  ('evolutionary', 7248),
#  ('transform', 7222),
#  ('content', 7208),
#  ('constrained', 7175),
#  ('inference', 7146),
#  ('metric', 7140),
#  ('block', 7122),
#  ('probability', 7115),
#  ('difference', 7088),
#  ('series', 7066),
#  ('markov', 7066),
#  ('fusion', 7012),
#  ('relation', 7005),
#  ('brain', 6994),
#  ('area', 6985),
#  ('future', 6949),
#  ('verification', 6943),
#  ('gaussian', 6903),
#  ('concept', 6886),
#  ('methodology', 6869),
#  ('structural', 6831),
#  ('mode', 6829),
#  ('experimental', 6816),
#  ('multimedia', 6814),
#  ('location', 6813),
#  ('face', 6779),
#  ('effective', 6777),
#  ('automaton', 6776),
#  ('building', 6774),
#  ('education', 6764),
#  ('medical', 6762),
#  ('event', 6762),
#  ('context', 6733),
#  ('wavelet', 6727),
#  ('editor', 6711),
#  ('health', 6709),
#  ('region', 6701),
#  ('student', 6683),
#  ('sampling', 6673),
#  ('expression', 6643),
#  ('der', 6629),
#  ('making', 6580),
#  ('visualization', 6571),
#  ('characteristic', 6550),
#  ('transformation', 6542),
#  ('training', 6518),
#  ('extension', 6517),
#  ('und', 6502),
#  ('influence', 6468),
#  ('particle', 6451),
#  ('target', 6443),
#  ('interval', 6443),
#  ('relationship', 6441),
#  ('edge', 6438),
#  ('different', 6413),
#  ('supply', 6394),
#  ('understanding', 6366),
#  ('flexible', 6339),
#  ('cycle', 6320),
#  ('$', 6305),
#  ('correlation', 6297),
#  ('mesh', 6283),
#  ('wave', 6266),
#  ('scalable', 6260),
#  ('kernel', 6254),
#  ('word', 6253),
#  ('privacy', 6226),
#  ('curve', 6213),
#  ('practice', 6212),
#  ('guest', 6208),
#  ('ad', 6206),
#  ('similarity', 6205),
#  ('mean', 6160),
#  ('discovery', 6148),
#  ('reasoning', 6132),
#  ('experience', 6116),
#  ('relay', 6115),
#  ('compression', 6065),
#  ('public', 6041),
#  ('extended', 6030),
#  ('market', 6007),
#  ('convex', 6004),
#  ('remote', 5994),
#  ('link', 5965),
#  ('mixed', 5954),
#  ('entropy', 5949),
#  ('storage', 5936),
#  ('improvement', 5918),
#  ('diffusion', 5912),
#  ('comparative', 5896),
#  ('real', 5874),
#  ('size', 5866),
#  ('heuristic', 5854),
#  ('geometric', 5852),
#  ('fading', 5848),
#  ('cluster', 5835),
#  ('diagnosis', 5820),
#  ('standard', 5805),
#  ('embedded', 5788),
#  ('investigation', 5781),
#  ('approximate', 5766),
#  ('convolutional', 5761),
#  ('experiment', 5747),
#  ('input', 5743),
#  ('molecular', 5741),
#  ('finding', 5738),
#  ('synchronization', 5733),
#  ('potential', 5701),
#  ('degree', 5684),
#  ('authentication', 5671),
#  ('criterion', 5668),
#  ('hoc', 5660),
#  ('current', 5655),
#  ('lattice', 5649),
#  ('scale', 5646),
#  ('natural', 5638),
#  ('sequential', 5630),
#  ('modified', 5627),
#  ('classifier', 5610),
#  ('production', 5602),
#  ('combining', 5573),
#  ('assignment', 5563),
#  ('correction', 5499),
#  ('family', 5495),
#  ('proof', 5457),
#  ('antenna', 5457),
#  ('intelligence', 5454),
#  ('requirement', 5452),
#  ('processor', 5437),
#  ('base', 5429),
#  ('enhancement', 5397),
#  ('uncertain', 5396),
#  ('load', 5383),
#  ('integral', 5367),
#  ('action', 5354),
#  ('output', 5295),
#  ('evaluating', 5283),
#  ('fractional', 5278),
#  ('enhanced', 5259),
#  ('document', 5256),
#  ('recovery', 5243),
#  ('autonomous', 5225),
#  ('view', 5198),
#  ('modulation', 5197),
#  ('practical', 5183),
#  ('book', 5157),
#  ('algebra', 5153),
#  ('topology', 5125),
#  ('exploring', 5111),
#  ('resolution', 5102),
#  ('formal', 5089),
#  ('algebraic', 5086),
#  ('inverse', 5066),
#  ('radar', 5065),
#  ('world', 5061),
#  ('decoding', 5057),
#  ('ii', 5055),
#  ('switching', 5038),
#  ('dimension', 5028),
#  ('node', 5026),
#  ('square', 4985),
#  ('satellite', 4981),
#  ('presence', 4979),
#  ('exact', 4976),
#  ('inequality', 4975),
#  ('density', 4969),
#  ('net', 4968),
#  ('color', 4948),
#  ('symmetric', 4913),
#  ('applied', 4892),
#  ('adaptation', 4888),
#  ('signature', 4881),
#  ('big', 4853),
#  ('2', 4844),
#  ('accurate', 4834),
#  ('predictive', 4827),
#  ('message', 4820),
#  ('manufacturing', 4813),
#  ('lower', 4805),
#  ('planar', 4803),
#  ('&', 4803),
#  ('critical', 4789),
#  ('alignment', 4767),
#  ('designing', 4762),
#  ('failure', 4751),
#  ('direct', 4739),
#  ('swarm', 4721),
#  ('principle', 4716),
#  ('encryption', 4713),
#  ('mathematical', 4708),
#  ('unit', 4696),
#  ('report', 4692),
#  ('industry', 4687),
#  ('association', 4686),
#  ('predicting', 4680),
#  ('specification', 4675),
#  ('detecting', 4648),
#  ('urban', 4639),
#  ('packet', 4636),
#  ('ontology', 4636),
#  ('perception', 4626),
#  ('blind', 4618),
#  ('semantics', 4613),
#  ('connectivity', 4589),
#  ('scientific', 4585),
#  ('von', 4575),
#  ('diversity', 4555),
#  ('time-varying', 4550),
#  ('procedure', 4528),
#  ('receiver', 4510),
#  ('variation', 4504),
#  ('quadratic', 4497),
#  ('form', 4488),
#  ('patient', 4477),
#  ('layer', 4476),
#  ('disease', 4474),
#  ('periodic', 4467),
#  ('asymptotic', 4467),
#  ('validation', 4466),
#  ('gradient', 4453),
#  ('cmos', 4451),
#  ('propagation', 4444),
#  ('volume', 4443),
#  ('geometry', 4439),
#  ('demand', 4420),
#  ('weight', 4417),
#  ('converter', 4415),
#  ('site', 4407),
#  ('hardware', 4400),
#  ('complete', 4396),
#  ('integrating', 4393),
#  ('paper', 4360),
#  ('vision', 4355),
#  ('university', 4336),
#  ('ieee', 4326),
#  ('infrastructure', 4325),
#  ('orthogonal', 4317),
#  ('developing', 4312),
#  ('navigation', 4306),
#  ('water', 4294),
#  ('equilibrium', 4290),
#  ('physical', 4285),
#  ('evidence', 4285),
#  ('multi-agent', 4282),
#  ('basis', 4275),
#  ('structured', 4262),
#  ('innovation', 4261),
#  ('range', 4247),
#  ('description', 4241),
#  ('estimating', 4238),
#  ('three-dimensional', 4228),
#  ('ensemble', 4222),
#  ('soft', 4217),
#  ('projection', 4213),
#  ('stream', 4202),
#  ('trajectory', 4174),
#  ('coupled', 4167),
#  ('coefficient', 4162),
#  ('motor', 4139),
#  ('regular', 4135),
#  ('comment', 4134),
#  ('law', 4133),
#  ('free', 4131),
#  ('bounded', 4130),
#  ('minimal', 4128),
#  ('dual', 4114),
#  ('trust', 4109),
#  ('moving', 4094),
#  ('minimization', 4090),
#  ('expert', 4085),
#  ('exponential', 4076),
#  ('aggregation', 4060),
#  ('accuracy', 4060),
#  ('recommendation', 4054),
#  ('magnetic', 4053),
#  ('robotic', 4046),
#  ('versus', 4044),
#  ('transport', 4044),
#  ('unified', 4036),
#  ('common', 4020),
#  ('industrial', 4019),
#  ('independent', 4019),
#  ('integer', 4009),
#  ('exploration', 4002),
#  ('server', 4001),
#  ('quantitative', 3998),
#  ('stable', 3991),
#  ('sar', 3991),
#  ('term', 3981),
#  ('improve', 3970),
#  ('reference', 3963),
#  ('implication', 3963),
#  ('multivariate', 3962),
#  ('measuring', 3939),
#  ('limit', 3938),
#  ('enterprise', 3928),
#  ('estimate', 3918),
#  ('length', 3900),
#  ('two-dimensional', 3896),
#  ('recursive', 3893),
#  ('interpolation', 3893),
#  ('variational', 3892),
#  ('related', 3874),
#  ('international', 3863),
#  ('threshold', 3862),
#  ('generating', 3861),
#  ('plane', 3852),
#  ('exploiting', 3846),
#  ('profile', 3827),
#  ('camera', 3817),
#  ('transition', 3816),
#  ('invariant', 3813),
#  ('preference', 3811),
#  ('teaching', 3803),
#  ('loss', 3788),
#  ('1', 3786),
#  ('embedding', 3780),
#  ('multi-objective', 3778),
#  ('preface', 3774),
#  ('mixture', 3765),
#  ('combinatorial', 3765),
#  ('supporting', 3763),
#  ('observation', 3762),
#  ('simultaneous', 3756),
#  ('asynchronous', 3753),
#  ('identifying', 3740),
#  ('v', 3738),
#  ('sample', 3731),
#  ('ofdm', 3729),
#  ('combined', 3728),
#  ('cancer', 3725),
#  ('voltage', 3724),
#  ('advanced', 3720),
#  ('für', 3715),
#  ('dynamical', 3713),
#  ('sensitivity', 3709),
#  ('boolean', 3709),
#  ('unsupervised', 3707),
#  ('universal', 3707),
#  ('separation', 3707),
#  ('reality', 3706),
#  ('acquisition', 3705),
#  ('formation', 3695),
#  ('consensus', 3688),
#  ('systematic', 3680),
#  ('ranking', 3677),
#  ('fixed', 3667),
#  ('organization', 3662),
#  ('thing', 3659),
#  ('reliable', 3659),
#  ('positive', 3649),
#  ('total', 3647),
#  ('attribute', 3644),
#  ('temperature', 3631),
#  ('manipulator', 3629),
#  ('mobility', 3625),
#  ('statistic', 3624),
#  ('energy-efficient', 3624),
#  ('strong', 3616),
#  ('life', 3612),
#  ('streaming', 3605),
#  ('clinical', 3605),
#  ('work', 3602),
#  ('discrete-time', 3600),
#  ('body', 3598),
#  ('theoretical', 3589),
#  ('translation', 3582),
#  ('texture', 3582),
#  ('direction', 3570),
#  ('forest', 3562),
#  ('center', 3558),
#  ('reinforcement', 3542),
#  ('stabilization', 3538),
#  ('protection', 3538),
#  ('generator', 3530),
#  ('existence', 3519),
#  ('force', 3518),
#  ('forecasting', 3515),
#  ('calibration', 3515),
#  ('optimizing', 3512),
#  ('chaotic', 3499),
#  ('calculation', 3493),
#  ('recurrent', 3492),
#  ('acoustic', 3489),
#  ('parametric', 3479),
#  ('networking', 3479),
#  ('speed', 3477),
#  ('population', 3475),
#  ('scene', 3450),
#  ('second', 3447),
#  ('chemical', 3437),
#  ('multicast', 3436),
#  ('fully', 3425),
#  ('analyzing', 3423),
#  ('composition', 3416),
#  ('partition', 3414),
#  ('model-based', 3412),
#  ('analytical', 3407),
#  ('higher', 3404),
#  ('unknown', 3395),
#  ('queue', 3388),
#  ('permutation', 3381),
#  ('material', 3373),
#  ('maintenance', 3371),
#  ('configuration', 3371),
#  ('overview', 3367),
#  ('managing', 3364),
#  ('abstract', 3359),
#  ('broadcast', 3358),
#  ('pricing', 3357),
#  ('assessing', 3355),
#  ('individual', 3350),
#  ('relational', 3347),
#  ('subspace', 3340),
#  ('biological', 3340),
#  ('personal', 3339),
#  ('modular', 3337),
#  ('thermal', 3328),
#  ('hidden', 3328),
#  ('registration', 3323),
#  ('compact', 3322),
#  ('optimized', 3321),
#  ('delivery', 3318),
#  ('depth', 3302),
#  ('balancing', 3302),
#  ('ring', 3297),
#  ('incremental', 3296),
#  ('formula', 3292),
#  ('deterministic', 3292),
#  ('3-d', 3287),
#  ('aspect', 3276),
#  ('alternative', 3274),
#  ('enhancing', 3271),
#  ('chinese', 3264),
#  ('qos', 3263),
#  ('compensation', 3262),
#  ('constant', 3258),
#  ('trend', 3255),
#  ('factorization', 3255),
#  ('r', 3247),
#  ('collaboration', 3246),
#  ('expansion', 3242),
#  ('hyperspectral', 3241),
#  ('formulation', 3237),
#  ('sum', 3236),
#  ('customer', 3233),
#  ('loop', 3231),
#  ('choice', 3230),
#  ('static', 3226),
#  ('growth', 3221),
#  ('topological', 3220),
#  ('massive', 3208),
#  ('exchange', 3206),
#  ('example', 3193),
#  ('generalization', 3183),
#  ('bandwidth', 3182),
#  ('partitioning', 3180),
#  ('indoor', 3173),
#  ('decentralized', 3172),
#  ('strategic', 3171),
#  ('engine', 3170),
#  ('concurrent', 3170),
#  ('hierarchy', 3167),
#  ('electric', 3166),
#  ('estimator', 3161),
#  ('detector', 3159),
#  ('coordination', 3159),
#  ('short', 3152),
#  ('la', 3145),
#  ('reconfigurable', 3138),
#  ('elliptic', 3138),
#  ('dna', 3138),
#  ('connected', 3122),
#  ('job', 3120),
#  ('collection', 3115),
#  ('2d', 3113),
#  ('singular', 3107),
#  ('early', 3106),
#  ('imagery', 3101),
#  ('light', 3097),
#  ('conference', 3097),
#  ('capability', 3080),
#  ('literature', 3079),
#  ('multidimensional', 3078),
#  ('multiuser', 3072),
#  ('plant', 3071),
#  ('display', 3071),
#  ('beamforming', 3069),
#  ('tensor', 3064),
#  ('safety', 3064),
#  ('movement', 3059),
#  ('conditional', 3057),
#  ('news', 3055),
#  ('scaling', 3054),
#  ('technical', 3048),
#  ('determination', 3045),
#  ('price', 3038),
#  ('ratio', 3035),
#  ('cyclic', 3033),
#  ('arithmetic', 3027),
#  ('die', 3024),
#  ('noisy', 3023),
#  ('journal', 3020),
#  ('arbitrary', 3019),
#  ('frame', 3013),
#  ('uniform', 3009),
#  ('infinite', 3007),
#  ('generic', 3006),
#  ('combination', 3005),
#  ('correlated', 2991),
#  ('course', 2986),
#  ('coverage', 2981),
#  ('annotation', 2976),
#  ('environmental', 2975),
#  ('position', 2974),
#  ('identity', 2968),
#  ('object-oriented', 2967),
#  ('rational', 2966),
#  ('second-order', 2964),
#  ('fluid', 2964),
#  ('behaviour', 2959),
#  ('china', 2955),
#  ('web-based', 2950),
#  ('adoption', 2949),
#  ('rough', 2936),
#  ('rank', 2933),
#  ('highly', 2932),
#  ('h', 2930),
#  ('team', 2923),
#  ('belief', 2923),
#  ('normal', 2920),
#  ('module', 2919),
#  ('encoding', 2918),
#  ('version', 2912),
#  ('average', 2912),
#  ('coupling', 2909),
#  ('vehicular', 2902),
#  ('placement', 2898),
#  ('shared', 2892),
#  ('inventory', 2884),
#  ('record', 2882),
#  ('upper', 2877),
#  ('vertex', 2869),
#  ('calculus', 2868),
#  ('section', 2867),
#  ('compressed', 2860),
#  ('assembly', 2858),
#  ('grammar', 2857),
#  ('optimisation', 2855),
#  ('conceptual', 2852),
#  ('applying', 2849),
#  ('advance', 2834),
#  ('cover', 2831),
#  ('weak', 2827),
#  ('multimodal', 2823),
#  ('relative', 2819),
#  ('throughput', 2809),
#  ('consumer', 2808),
#  ('searching', 2806),
#  ('equivalence', 2798),
#  ('scenario', 2775),
#  ('comprehensive', 2771),
#  ('interpretation', 2763),
#  ('file', 2757),
#  ('connection', 2757),
#  ('composite', 2757),
#  ('usage', 2743),
#  ('space-time', 2734),
#  ('analytics', 2731),
#  ('controlled', 2716),
#  ('considering', 2713),
#  ('electrical', 2708),
#  ('care', 2706),
#  ('isbn', 2703),
#  ('carlo', 2700),
#  ('selective', 2696),
#  ('preserving', 2695),
#  ('graphic', 2690),
#  ('multilevel', 2689),
#  ('sliding', 2688),
#  ('update', 2686),
#  ('high-speed', 2679),
#  ('fourier', 2678),
#  ('passive', 2677),
#  ('descriptor', 2677),
#  ('directed', 2674),
#  ('checking', 2670),
#  ('p', 2668),
#  ('workflow', 2659),
#  ('quantization', 2658),
#  ('cooperation', 2653),
#  ('double', 2652),
#  ('constructing', 2650),
#  ('induction', 2647),
#  ('robustness', 2646),
#  ('core', 2645),
#  ('driven', 2643),
#  ('networked', 2639),
#  ('counting', 2635),
#  ('coloring', 2632),
#  ('diagram', 2631),
#  ('on-line', 2628),
#  ('laser', 2626),
#  ('conjecture', 2616),
#  ('analog', 2614),
#  ('economic', 2611),
#  ('monte', 2609),
#  ('paradigm', 2607),
#  ('good', 2607),
#  ('cache', 2607),
#  ('mri', 2606),
#  ('limited', 2604),
#  ('iot', 2603),
#  ('home', 2603),
#  ('window', 2596),
#  ('facial', 2595),
#  ('explicit', 2591),
#  ('attention', 2591),
#  ('workshop', 2588),
#  ('petri', 2584),
#  ('rfid', 2583),
#  ('character', 2581),
#  ('consistency', 2574),
#  ('academic', 2571),
#  ('organizational', 2566),
#  ('healthcare', 2565),
#  ('augmented', 2562),
#  ('neuron', 2560),
#  ('pair', 2556),
#  ('c', 2550),
#  ('perfect', 2544),
#  ('perturbation', 2543),
#  ('long', 2537),
#  ('eigenvalue', 2532),
#  ('regularization', 2531),
#  ('road', 2528),
#  ('comparing', 2526),
#  ('binding', 2521),
#  ('reduced', 2513),
#  ('associated', 2513),
#  ('transportation', 2510),
#  ('educational', 2508),
#  ('symbolic', 2505),
#  ('doe', 2504),
#  ('financial', 2503),
#  ('maximal', 2502),
#  ('implicit', 2501),
#  ('recent', 2500),
#  ('effectiveness', 2499),
#  ('genome', 2498),
#  ('regulation', 2496),
#  ('reducing', 2494),
#  ('watermarking', 2493),
#  ('likelihood', 2491),
#  ('execution', 2490),
#  ('need', 2488),
#  ('land', 2481),
#  ('erratum', 2478),
#  ('best', 2476),
#  ('supervised', 2475),
#  ('revisited', 2475),
#  ('people', 2474),
#  ('music', 2474),
#  ('multiscale', 2473),
#  ('downlink', 2473),
#  ('k', 2462),
#  ('switched', 2461),
#  ('reaction', 2461),
#  ('induced', 2461),
#  ('covering', 2455),
#  ('subject', 2447),
#  ...]

# %%
top_keywords = [word_count[0] for word_count in keyword_counts[:100]]
print(top_keywords)
# Out:
# ['system', 'network', 'model', 'analysis', 'algorithm', 'data', 'method', 'approach', 'problem', 'application', 'control', 'learning', 'design', 'image', 'information', 'dynamic', 'graph', 'detection', 'study', 'new', 'performance', 'optimization', 'wireless', 'neural', 'estimation', 'adaptive', 'efficient', 'fuzzy', 'sensor', 'linear', 'modeling', 'function', 'scheme', 'optimal', 'mobile', 'management', 'distributed', 'time', 'communication', 'channel', 'process', 'equation', 'service', 'framework', 'power', 'classification', 'evaluation', 'set', 'structure', 'software', 'technique', 'simulation', 'code', 'multiple', 'environment', 'computing', 'recognition', 'solution', 'robust', 'nonlinear', 'effect', 'theory', 'machine', 'feature', 'case', 'technology', 'social', 'parallel', 'development', 'architecture', 'scheduling', 'selection', 'hybrid', 'programming', 'digital', 'decision', 'space', 'signal', 'web', 'search', 'protocol', 'novel', 'prediction', 'online', 'logic', 'knowledge', 'energy', 'language', 'fast', 'research', 'video', 'strategy', 'computer', 'pattern', 'matrix', 'support', 'review', 'stochastic', 'random', 'implementation']

# %%
top_keyword_topics = dict()
for top_keyword in top_keywords:
    top_keyword_topics[top_keyword] = sorted(lda_model_bow.get_term_topics(top_keyword), key=lambda tup:tup[1], reverse=True)

# %%
top_keyword_topics
# Out:
# {'system': [(9, 0.14086567),
#   (0, 0.033819497),
#   (7, 0.033084434),
#   (10, 0.017416175),
#   (2, 0.00021401412),
#   (3, 9.423286e-06),
#   (6, 4.832772e-06)],
#  'network': [(10, 0.09500348), (8, 0.025520677)],
#  'model': [(2, 0.030992398),
#   (1, 0.030761773),
#   (9, 0.013784084),
#   (8, 0.009588864),
#   (3, 0.008281472),
#   (0, 0.008184194),
#   (6, 0.006767093),
#   (11, 0.0030651824),
#   (10, 0.00012178734),
#   (12, 2.3604172e-05),
#   (5, 6.0191064e-06),
#   (7, 1.5290514e-07)],
#  'analysis': [(2, 0.019118698),
#   (3, 0.016167935),
#   (1, 0.014031882),
#   (0, 0.00980979),
#   (9, 0.00855227),
#   (8, 0.007563124),
#   (7, 0.007501577),
#   (4, 0.0071428004),
#   (10, 0.006907436),
#   (11, 0.005732793),
#   (6, 0.0052868496),
#   (12, 0.0025187656),
#   (5, 0.00247623)],
#  'algorithm': [(6, 0.054443173),
#   (5, 0.015100211),
#   (8, 0.01159434),
#   (0, 0.010894981),
#   (10, 0.009656792),
#   (3, 1.16432425e-07)],
#  'data': [(1, 0.061110325),
#   (4, 0.019647451),
#   (2, 0.015235735),
#   (8, 8.657257e-07)],
#  'method': [(6, 0.037847985),
#   (2, 0.013147836),
#   (8, 0.012305759),
#   (3, 0.008201336),
#   (5, 0.0033596545),
#   (9, 1.0250945e-06),
#   (4, 1.5776406e-08)],
#  'approach': [(2, 0.03315996),
#   (9, 0.015181577),
#   (1, 0.012787669),
#   (8, 0.009713976),
#   (0, 0.008847755),
#   (6, 7.860674e-06)],
#  'problem': [(6, 0.06385919)],
#  'application': [(7, 0.012216063),
#   (0, 0.008271267),
#   (4, 0.00718096),
#   (9, 0.0070150415),
#   (2, 0.006689351),
#   (10, 0.00561146),
#   (8, 0.0055504767),
#   (6, 0.005021257),
#   (5, 0.00443837),
#   (1, 0.0024940537),
#   (11, 0.0020667294),
#   (3, 0.001341457),
#   (12, 0.000547576)],
#  'control': [(9, 0.07174467)],
#  'learning': [(2, 0.030008081), (11, 0.011935081), (8, 0.00919585)],
#  'design': [(7, 0.03953455),
#   (9, 0.01502163),
#   (0, 0.0120007545),
#   (10, 0.0039747367),
#   (3, 1.964297e-06)],
#  'image': [(8, 0.054312903)],
#  'information': [(12, 0.036656525),
#   (11, 0.015080984),
#   (1, 0.011034072),
#   (7, 0.0002739988)],
#  'dynamic': [(9, 0.009267621),
#   (10, 0.008395096),
#   (2, 0.008360541),
#   (3, 0.005272706),
#   (6, 0.005054229),
#   (0, 0.0050054314),
#   (1, 0.004962876),
#   (8, 0.0028589189)],
#  'graph': [(5, 0.07274624)],
#  'detection': [(8, 0.037184387)],
#  'study': [(11, 0.044240717)],
#  'new': [(6, 0.009330844),
#   (5, 0.006748841),
#   (7, 0.005432008),
#   (11, 0.0047024908),
#   (0, 0.0038948671),
#   (1, 0.0032009885),
#   (2, 0.0025022384),
#   (9, 0.0024155255),
#   (4, 0.0022176735),
#   (8, 0.0022148264),
#   (12, 0.0012457502),
#   (10, 0.0006639671),
#   (3, 0.00017207114)],
#  'performance': [(3, 0.013850034),
#   (10, 0.008098177),
#   (0, 0.007320748),
#   (11, 0.005771318),
#   (7, 0.003215364),
#   (9, 0.0024961215),
#   (2, 0.00225788),
#   (4, 2.57393e-05)],
#  'optimization': [(6, 0.029774131),
#   (10, 0.0059694275),
#   (3, 0.004864681),
#   (9, 0.00081042026)],
#  'wireless': [(10, 0.028229183)],
#  'neural': [(8, 0.026951479)],
#  'estimation': [(3, 0.02813608), (8, 0.006637421)],
#  'adaptive': [(9, 0.021719515),
#   (8, 0.006572441),
#   (10, 0.0055750604),
#   (3, 0.002045226),
#   (6, 1.4050139e-05)],
#  'efficient': [(0, 0.011282818),
#   (10, 0.007338454),
#   (6, 0.004147136),
#   (8, 0.0041051735),
#   (5, 0.0036813386),
#   (4, 0.0028479306),
#   (3, 9.41043e-07)],
#  'fuzzy': [(9, 0.029333724)],
#  'sensor': [(10, 0.027863156), (8, 5.2496725e-06)],
#  'linear': [(6, 0.017763438), (9, 0.006423008), (5, 0.0048652007)],
#  'modeling': [(2, 0.025221188), (3, 0.006542848), (9, 5.976069e-05)],
#  'function': [(5, 0.020480016), (6, 0.0068666423)],
#  'scheme': [(0, 0.01826352), (10, 0.00789474), (3, 0.002319151)],
#  'optimal': [(9, 0.009860957),
#   (6, 0.0058357525),
#   (10, 0.0043405695),
#   (5, 0.004219275),
#   (0, 0.0021013217),
#   (3, 0.0005881856)],
#  'mobile': [(10, 0.028085921), (12, 1.9444772e-06)],
#  'management': [(1, 0.014591322),
#   (10, 0.0062349825),
#   (11, 0.0046067317),
#   (0, 0.004149605),
#   (7, 0.0025881685)],
#  'distributed': [(10, 0.013579081), (0, 0.00610917), (9, 0.0051734997)],
#  'time': [(6, 0.03128037)],
#  'communication': [(10, 0.02238876), (3, 0.003531255), (12, 9.518075e-08)],
#  'channel': [(3, 0.026026733)],
#  'process': [(1, 0.041070163)],
#  'equation': [(6, 0.0152597865)],
#  'service': [(12, 0.016074505), (10, 0.0073996084), (0, 0.0053448197)],
#  'framework': [(1, 0.012392804),
#   (2, 0.0053324886),
#   (7, 0.004080128),
#   (0, 0.0032744096),
#   (10, 0.0026760518),
#   (12, 0.002394618),
#   (8, 1.9044704e-06)],
#  'power': [(10, 0.018495185), (3, 0.006270983)],
#  'classification': [(8, 0.019218529), (2, 0.0049112164)],
#  'evaluation': [(7, 0.008219533),
#   (0, 0.0042449683),
#   (11, 0.003933858),
#   (2, 0.0039039038),
#   (3, 0.003320822),
#   (12, 0.0027531881),
#   (10, 0.002673515),
#   (9, 0.0019760404),
#   (8, 0.00038001587)],
#  'set': [(5, 0.026245851)],
#  'structure': [(1, 0.010222801),
#   (5, 0.0051216106),
#   (2, 0.0032443115),
#   (9, 0.002475452),
#   (3, 0.002182719),
#   (8, 0.0021631382),
#   (12, 0.00061513274),
#   (6, 4.779482e-07)],
#  'software': [(7, 0.0424798)],
#  'technique': [(4, 0.0061830464),
#   (2, 0.0048818905),
#   (3, 0.004438006),
#   (8, 0.004306795),
#   (7, 0.004102841),
#   (0, 0.0037435626),
#   (10, 0.0017597363),
#   (6, 0.0017369292),
#   (5, 4.990588e-07)],
#  'simulation': [(3, 0.022981307)],
#  'code': [(3, 0.016275918),
#   (5, 0.0072269007),
#   (0, 0.0025650926),
#   (4, 5.964937e-05)],
#  'multiple': [(10, 0.0044447365),
#   (8, 0.0042859395),
#   (9, 0.004115267),
#   (3, 0.0034679018),
#   (6, 0.0017196436),
#   (5, 0.0016238677),
#   (2, 0.0015950918),
#   (1, 0.0014104511),
#   (0, 0.00070749945),
#   (4, 0.00042677036)],
#  'environment': [(7, 0.01803863),
#   (10, 0.0053111166),
#   (0, 0.00408667),
#   (2, 0.0005490454)],
#  'computing': [(0, 0.026254013)],
#  'recognition': [(8, 0.026611002)],
#  'solution': [(6, 0.019629734)],
#  'robust': [(9, 0.01565492), (8, 0.0072282725)],
#  'nonlinear': [(6, 0.023534304)],
#  'effect': [(3, 0.009585956),
#   (11, 0.006264336),
#   (12, 0.004653777),
#   (2, 0.003132313),
#   (7, 0.0029713896)],
#  'theory': [(11, 0.0124109), (5, 0.0041804956), (9, 0.0032387008)],
#  'machine': [(2, 0.013411271),
#   (9, 0.004943037),
#   (0, 0.003459411),
#   (6, 9.140655e-08)],
#  'feature': [(8, 0.021904105)],
#  'case': [(11, 0.02326751)],
#  'technology': [(11, 0.019938914), (7, 0.0036933615), (12, 0.00010593457)],
#  'social': [(12, 0.026892453)],
#  'parallel': [(0, 0.02443095)],
#  'development': [(7, 0.027858851)],
#  'architecture': [(0, 0.01388765), (7, 0.004503997), (10, 0.0029536637)],
#  'scheduling': [(0, 0.009197455), (6, 0.004725427), (10, 0.0038002657)],
#  'selection': [(8, 0.0057273284),
#   (2, 0.0036310214),
#   (9, 0.0032750717),
#   (10, 0.0031102113),
#   (3, 0.0023597197),
#   (6, 0.0020175977),
#   (5, 1.5003789e-06)],
#  'hybrid': [(9, 0.0055035492),
#   (6, 0.0039575384),
#   (10, 0.003059079),
#   (2, 0.0021529489),
#   (8, 0.0019243241),
#   (0, 0.0018173729),
#   (3, 0.0008685615)],
#  'programming': [(6, 0.01638006), (0, 0.00404075)],
#  'digital': [(7, 0.016808288), (4, 0.0059713693)],
#  'decision': [(9, 0.017253289)],
#  'space': [(5, 0.017562116)],
#  'signal': [(4, 0.015134884), (3, 0.0062864074), (8, 0.0038726036)],
#  'web': [(12, 0.024810167)],
#  'search': [(5, 0.011393227), (12, 0.0055274614)],
#  'protocol': [(10, 0.009932138), (0, 0.003230637)],
#  'novel': [(8, 0.004387289),
#   (2, 0.0037947067),
#   (10, 0.003174923),
#   (9, 0.0025372219),
#   (3, 0.0024732244),
#   (6, 0.0017499736)],
#  'prediction': [(2, 0.013596821), (8, 0.001087421)],
#  'online': [(12, 0.020456145)],
#  'logic': [(9, 0.014455518)],
#  'knowledge': [(1, 0.029527865)],
#  'energy': [(10, 0.009965374), (3, 0.0030092394)],
#  'language': [(11, 0.017389389)],
#  'fast': [(8, 0.0064545334),
#   (4, 0.0042142803),
#   (6, 0.0027847295),
#   (0, 0.0022373241),
#   (5, 0.0022146227)],
#  'research': [(11, 0.019042218), (7, 0.0042718123), (12, 8.91796e-06)],
#  'video': [(12, 0.020782106)],
#  'strategy': [(10, 0.0032866893),
#   (11, 0.002692512),
#   (9, 0.0026243296),
#   (12, 0.0022187384),
#   (0, 0.002004728),
#   (7, 0.00200183),
#   (1, 0.0017218663),
#   (6, 0.0015681472),
#   (2, 0.0012631922),
#   (4, 2.3156967e-05),
#   (3, 4.8034703e-06)],
#  'computer': [(11, 0.011775914), (7, 0.0058785337)],
#  'pattern': [(2, 0.01540491), (8, 0.006981331), (12, 5.5472112e-05)],
#  'matrix': [(5, 0.014024952)],
#  'support': [(9, 0.018702371), (7, 0.00084619486)],
#  'review': [(7, 0.01431725), (11, 0.0035081813)],
#  'stochastic': [(6, 0.011173192), (9, 0.0034503879)],
#  'random': [(5, 0.012717241)],
#  'implementation': [(0, 0.019936157)]}

# %%
top_keyword_top_topic = {term:-1 if topics == [] else topics[0][0] for term,topics in top_keyword_topics.items()}
top_keyword_top_topic
# Out:
# {'system': 9,
#  'network': 10,
#  'model': 2,
#  'analysis': 2,
#  'algorithm': 6,
#  'data': 1,
#  'method': 6,
#  'approach': 2,
#  'problem': 6,
#  'application': 7,
#  'control': 9,
#  'learning': 2,
#  'design': 7,
#  'image': 8,
#  'information': 12,
#  'dynamic': 9,
#  'graph': 5,
#  'detection': 8,
#  'study': 11,
#  'new': 6,
#  'performance': 3,
#  'optimization': 6,
#  'wireless': 10,
#  'neural': 8,
#  'estimation': 3,
#  'adaptive': 9,
#  'efficient': 0,
#  'fuzzy': 9,
#  'sensor': 10,
#  'linear': 6,
#  'modeling': 2,
#  'function': 5,
#  'scheme': 0,
#  'optimal': 9,
#  'mobile': 10,
#  'management': 1,
#  'distributed': 10,
#  'time': 6,
#  'communication': 10,
#  'channel': 3,
#  'process': 1,
#  'equation': 6,
#  'service': 12,
#  'framework': 1,
#  'power': 10,
#  'classification': 8,
#  'evaluation': 7,
#  'set': 5,
#  'structure': 1,
#  'software': 7,
#  'technique': 4,
#  'simulation': 3,
#  'code': 3,
#  'multiple': 10,
#  'environment': 7,
#  'computing': 0,
#  'recognition': 8,
#  'solution': 6,
#  'robust': 9,
#  'nonlinear': 6,
#  'effect': 3,
#  'theory': 11,
#  'machine': 2,
#  'feature': 8,
#  'case': 11,
#  'technology': 11,
#  'social': 12,
#  'parallel': 0,
#  'development': 7,
#  'architecture': 0,
#  'scheduling': 0,
#  'selection': 8,
#  'hybrid': 9,
#  'programming': 6,
#  'digital': 7,
#  'decision': 9,
#  'space': 5,
#  'signal': 4,
#  'web': 12,
#  'search': 5,
#  'protocol': 10,
#  'novel': 8,
#  'prediction': 2,
#  'online': 12,
#  'logic': 9,
#  'knowledge': 1,
#  'energy': 10,
#  'language': 11,
#  'fast': 8,
#  'research': 11,
#  'video': 12,
#  'strategy': 10,
#  'computer': 11,
#  'pattern': 2,
#  'matrix': 5,
#  'support': 9,
#  'review': 7,
#  'stochastic': 6,
#  'random': 5,
#  'implementation': 0}

# %% [markdown]
# ## Save Outputs

# %% [markdown]
# ### 1. Trained Models

# %%
lda_model_bow.save('./model/lda_bow.model')

# %%
# Just testing if it can be read
test_model_read = models.LdaModel.load('./model/lda_bow.model', mmap='r')
for idx, topic in test_model_read.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))

# %%
lda_model_tfidf.save('./model/lda_tfidf.model')

# %% [markdown]
# ### 2. Keyword-topics

# %%
f = open("./data/top_keyword_top_topic.json","w")
json.dump(top_keyword_top_topic, f)
f.close()

# %% [markdown]
# ## Clear Data

# %%
del test_title
del test_title_lemma
del test_title_lemma_dict


del test_model_read
