# %% [markdown]
# ## General Utilities

# %%
import string
import csv
import json

import gensim
from gensim import corpora, models

# %%
def print_first_n_dict_items(d: dict, dict_name: str, n: int):
    print("\nPrinting first", n, "items of dict named", dict_name, "\n========================================================")
    i = 0
    for key, value in d.items():
        print(key, ":", value)
        i += 1
        if i == n:
            break

# %%
def print_document_word_counts(document, doc_word_dict, mode):
    if mode == 'BOW':
        for i in range(len(document)):
            print("Word {} (\"{}\") appears {} time.".format(document[i][0], doc_word_dict[document[i][0]], document[i][1]))
    elif mode == 'TF_IDF':
        for i in range(len(document)):
            print("Word {} (\"{}\")'s TF-IDF is {}.".format(document[i][0], doc_word_dict[document[i][0]], document[i][1]))

# %%
def print_topics_from_model(model):
    for idx, topic in model.print_topics(-1):
        print('Topic: {} \nWords: {}'.format(idx, topic))

# %%
def generate_topic_prediction_scores(document, model):
    for index, score in sorted(model[document], key=lambda tup: -1*tup[1]):
        print("\nScore: {}\t \nTopic: {}\n{}".format(score, index, model.print_topic(index, 10)))

# %% [markdown]
# ## Load data

# %%
f = open("./data/titles_lemmatized.json","r")
title_terms_map = json.load(f)
f.close()

# %%
type(title_terms_map)
len(title_terms_map)
# Out:
# 1952578

# %%
print_first_n_dict_items(title_terms_map, "Titles: Original-Terms Map", 10)
# Out:
# Printing first 10 items of dict named Titles: Original-Terms Map
# ========================================================
# Parallel Integer Sorting and Simulation Amongst CRCW Models : ['parallel', 'integer', 'sorting', 'simulation', 'crcw', 'model']
# Pattern Matching in Trees and Nets : ['pattern', 'matching', 'tree', 'net']
# NP-complete Problems Simplified on Tree Schemas : ['np-complete', 'problem', 'simplified', 'tree', 'schema']
# On the Power of Chain Rules in Context Free Grammars : ['power', 'chain', 'rule', 'context', 'free', 'grammar']
# Schnelle Multiplikation von Polynomen über Körpern der Charakteristik 2 : ['schnelle', 'multiplikation', 'von', 'polynomen', 'über', 'körpern', 'der', 'charakteristik', '2']
# A characterization of rational D0L power series : ['characterization', 'rational', 'd0l', 'power', 'series']
# The Derivation of Systolic Implementations of Programs : ['derivation', 'systolic', 'implementation', 'program']
# Fifo Nets Without Order Deadlock : ['fifo', 'net', 'order', 'deadlock']
# On the Complementation Rule for Multivalued Dependencies in Database Relations : ['complementation', 'rule', 'multivalued', 'dependency', 'database', 'relation']
# Equational weighted tree transformations : ['equational', 'weighted', 'tree', 'transformation']

# %%
title_terms_map["A characterization of rational D0L power series"]
# Out:
# ['characterization', 'rational', 'd0l', 'power', 'series']

# %% [markdown]
# ## BOW

# %%
random_doc_id = 4310 # for testing

# %%
title_terms_list = list(title_terms_map.values())
title_terms_list[:10]
# Out:
# [['parallel', 'integer', 'sorting', 'simulation', 'crcw', 'model'],
#  ['pattern', 'matching', 'tree', 'net'],
#  ['np-complete', 'problem', 'simplified', 'tree', 'schema'],
#  ['power', 'chain', 'rule', 'context', 'free', 'grammar'],
#  ['schnelle',
#   'multiplikation',
#   'von',
#   'polynomen',
#   'über',
#   'körpern',
#   'der',
#   'charakteristik',
#   '2'],
#  ['characterization', 'rational', 'd0l', 'power', 'series'],
#  ['derivation', 'systolic', 'implementation', 'program'],
#  ['fifo', 'net', 'order', 'deadlock'],
#  ['complementation',
#   'rule',
#   'multivalued',
#   'dependency',
#   'database',
#   'relation'],
#  ['equational', 'weighted', 'tree', 'transformation']]

# %%
title_terms_dict = gensim.corpora.Dictionary(title_terms_list)

# %%
title_terms_dict.filter_extremes(no_below=15, no_above=0.5, keep_n=100000)

# %%
print(type(title_terms_dict))
print(len(title_terms_dict))
# Out:
# <class 'gensim.corpora.dictionary.Dictionary'>
# 31010

# %%
count = 0
for k, v in title_terms_dict.iteritems():
    print(k, v)
    count += 1
    if count > 15:
        break
# Out:
# 0 integer
# 1 model
# 2 parallel
# 3 simulation
# 4 sorting
# 5 matching
# 6 net
# 7 pattern
# 8 tree
# 9 np-complete
# 10 problem
# 11 schema
# 12 simplified
# 13 chain
# 14 context
# 15 free

# %%
bow_corpus = [title_terms_dict.doc2bow(title_terms) for title_terms in title_terms_list]

# %%
print(type(bow_corpus))
print(len(bow_corpus))
print(title_terms_dict.doc2bow(title_terms_list[0]))
print_document_word_counts(title_terms_dict.doc2bow(title_terms_list[0]), title_terms_dict, mode='BOW')
# Out:
# <class 'list'>
# 1952578
# [(0, 1), (1, 1), (2, 1), (3, 1), (4, 1)]
# Word 0 ("integer") appears 1 time.
# Word 1 ("model") appears 1 time.
# Word 2 ("parallel") appears 1 time.
# Word 3 ("simulation") appears 1 time.
# Word 4 ("sorting") appears 1 time.

# %%
print_document_word_counts(bow_corpus[random_doc_id], title_terms_dict, mode='BOW')
# Out:
# Word 67 ("algorithm") appears 1 time.
# Word 260 ("execution") appears 1 time.
# Word 282 ("composite") appears 1 time.
# Word 296 ("service") appears 1 time.
# Word 1741 ("partitioning") appears 1 time.
# Word 2060 ("web") appears 1 time.
# Word 3143 ("genetic") appears 1 time.
# Word 4115 ("decentralized") appears 1 time.

# %% [markdown]
# ## Load and Test model predictions

# %%
# Loading model
lda_model_bow = models.LdaModel.load('./model/lda_bow.model', mmap='r')

# %%
lda_model_bow = gensim.models.LdaMulticore(bow_corpus, id2word=title_terms_dict, num_topics=13, minimum_probability=0, 
                                           passes=2, workers=2)

# %%
for idx, topic in lda_model_bow.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))
# Out:
# Topic: 0 Word: 0.034*"system" + 0.026*"computing" + 0.024*"parallel" + 0.020*"implementation" + 0.018*"scheme" + 0.015*"noise" + 0.014*"architecture" + 0.014*"security" + 0.013*"survey" + 0.013*"queue"
# Topic: 1 Word: 0.061*"data" + 0.041*"process" + 0.031*"model" + 0.030*"knowledge" + 0.016*"und" + 0.015*"management" + 0.014*"analysis" + 0.013*"integration" + 0.013*"approach" + 0.013*"change"
# Topic: 2 Word: 0.033*"approach" + 0.031*"model" + 0.030*"learning" + 0.025*"modeling" + 0.019*"analysis" + 0.015*"pattern" + 0.015*"data" + 0.014*"planning" + 0.014*"prediction" + 0.013*"machine"
# Topic: 3 Word: 0.030*"measurement" + 0.028*"estimation" + 0.026*"channel" + 0.023*"simulation" + 0.017*"error" + 0.016*"code" + 0.016*"analysis" + 0.015*"cognitive" + 0.014*"performance" + 0.013*"field"
# Topic: 4 Word: 0.031*"processing" + 0.025*"large" + 0.024*"frequency" + 0.020*"data" + 0.019*"domain" + 0.015*"für" + 0.015*"signal" + 0.014*"transform" + 0.014*"challenge" + 0.013*"continuous"
# Topic: 5 Word: 0.073*"graph" + 0.026*"set" + 0.022*"number" + 0.021*"function" + 0.018*"space" + 0.017*"tree" + 0.015*"algorithm" + 0.015*"complexity" + 0.014*"matrix" + 0.014*"generalized"
# Topic: 6 Word: 0.064*"problem" + 0.054*"algorithm" + 0.038*"method" + 0.031*"time" + 0.030*"optimization" + 0.024*"nonlinear" + 0.020*"solution" + 0.019*"class" + 0.018*"linear" + 0.017*"finite"
# Topic: 7 Word: 0.042*"software" + 0.040*"design" + 0.033*"system" + 0.028*"development" + 0.019*"virtual" + 0.018*"engineering" + 0.018*"environment" + 0.017*"robot" + 0.017*"digital" + 0.014*"review"
# Topic: 8 Word: 0.054*"image" + 0.037*"detection" + 0.027*"neural" + 0.027*"recognition" + 0.026*"network" + 0.022*"feature" + 0.019*"classification" + 0.018*"object" + 0.014*"motion" + 0.013*"visual"
# Topic: 9 Word: 0.141*"system" + 0.072*"control" + 0.029*"fuzzy" + 0.022*"adaptive" + 0.019*"support" + 0.017*"decision" + 0.016*"robust" + 0.015*"approach" + 0.015*"design" + 0.014*"logic"
# Topic: 10 Word: 0.095*"network" + 0.028*"wireless" + 0.028*"mobile" + 0.028*"sensor" + 0.022*"communication" + 0.018*"power" + 0.017*"system" + 0.014*"distributed" + 0.012*"construction" + 0.011*"stability"
# Topic: 11 Word: 0.044*"study" + 0.023*"case" + 0.020*"technology" + 0.019*"research" + 0.017*"language" + 0.015*"information" + 0.014*"issue" + 0.014*"special" + 0.013*"science" + 0.012*"theory"
# Topic: 12 Word: 0.037*"information" + 0.027*"social" + 0.025*"web" + 0.021*"video" + 0.020*"online" + 0.020*"game" + 0.016*"service" + 0.015*"der" + 0.015*"internet" + 0.013*"semantic"

# %%
topic_labels = ['Systems', 'Data', 'ML', 'Signals', 'Signals', 'Algo', 'Algo',
               'Software', 'Vision', 'Control', 'Networks', 'Misc', 'Social']
labels_merged_map = {0:0, 1:1, 2:2, 3:3, 4:3, 5:4, 6:4, 7:5, 8:6, 9:7, 10:8, 11:9, 12:10}
topic_labels_merged = []
for topic_label in topic_labels:
    if topic_label not in topic_labels_merged:
        topic_labels_merged.append(topic_label)
topic_labels_merged
# Out:
# ['Systems',
#  'Data',
#  'ML',
#  'Signals',
#  'Algo',
#  'Software',
#  'Vision',
#  'Control',
#  'Networks',
#  'Misc',
#  'Social']

# %%
lda_model_bow[bow_corpus[random_doc_id]]
# Out:
# [(0, 0.15104198),
#  (1, 0.008548858),
#  (2, 0.008548858),
#  (3, 0.11962713),
#  (4, 0.11965558),
#  (5, 0.008548885),
#  (6, 0.21878205),
#  (7, 0.008548858),
#  (8, 0.008548877),
#  (9, 0.119605064),
#  (10, 0.008548916),
#  (11, 0.008548858),
#  (12, 0.21144612)]

# %%
print_document_word_scores(bow_corpus[random_doc_id], title_terms_dict, mode='BOW')
# Out:
# Word 67 ("algorithm") appears 1 time.
# Word 260 ("execution") appears 1 time.
# Word 282 ("composite") appears 1 time.
# Word 296 ("service") appears 1 time.
# Word 1741 ("partitioning") appears 1 time.
# Word 2060 ("web") appears 1 time.
# Word 3143 ("genetic") appears 1 time.
# Word 4115 ("decentralized") appears 1 time.

# %%
generate_topic_prediction_scores(bow_corpus[random_doc_id], lda_model_bow)
# Out:
# Score: 0.2188308984041214
# Topic: 6
# 0.064*"problem" + 0.054*"algorithm" + 0.038*"method" + 0.031*"time" + 0.030*"optimization" + 0.024*"nonlinear" + 0.020*"solution" + 0.019*"class" + 0.018*"linear" + 0.017*"finite"
#
# Score: 0.21153035759925842
# Topic: 12
# 0.037*"information" + 0.027*"social" + 0.025*"web" + 0.021*"video" + 0.020*"online" + 0.020*"game" + 0.016*"service" + 0.015*"der" + 0.015*"internet" + 0.013*"semantic"
#
# Score: 0.15090879797935486
# Topic: 0
# 0.034*"system" + 0.026*"computing" + 0.024*"parallel" + 0.020*"implementation" + 0.018*"scheme" + 0.015*"noise" + 0.014*"architecture" + 0.014*"security" + 0.013*"survey" + 0.013*"queue"
#
# Score: 0.11965559422969818
# Topic: 4
# 0.031*"processing" + 0.025*"large" + 0.024*"frequency" + 0.020*"data" + 0.019*"domain" + 0.015*"für" + 0.015*"signal" + 0.014*"transform" + 0.014*"challenge" + 0.013*"continuous"
#
# Score: 0.11962714791297913
# Topic: 3
# 0.030*"measurement" + 0.028*"estimation" + 0.026*"channel" + 0.023*"simulation" + 0.017*"error" + 0.016*"code" + 0.016*"analysis" + 0.015*"cognitive" + 0.014*"performance" + 0.013*"field"
#
# Score: 0.11960506439208984
# Topic: 9
# 0.141*"system" + 0.072*"control" + 0.029*"fuzzy" + 0.022*"adaptive" + 0.019*"support" + 0.017*"decision" + 0.016*"robust" + 0.015*"approach" + 0.015*"design" + 0.014*"logic"
#
# Score: 0.008548916317522526
# Topic: 10
# 0.095*"network" + 0.028*"wireless" + 0.028*"mobile" + 0.028*"sensor" + 0.022*"communication" + 0.018*"power" + 0.017*"system" + 0.014*"distributed" + 0.012*"construction" + 0.011*"stability"
#
# Score: 0.008548884652554989
# Topic: 5
# 0.073*"graph" + 0.026*"set" + 0.022*"number" + 0.021*"function" + 0.018*"space" + 0.017*"tree" + 0.015*"algorithm" + 0.015*"complexity" + 0.014*"matrix" + 0.014*"generalized"
#
# Score: 0.008548877201974392
# Topic: 8
# 0.054*"image" + 0.037*"detection" + 0.027*"neural" + 0.027*"recognition" + 0.026*"network" + 0.022*"feature" + 0.019*"classification" + 0.018*"object" + 0.014*"motion" + 0.013*"visual"
#
# Score: 0.008548857644200325
# Topic: 1
# 0.061*"data" + 0.041*"process" + 0.031*"model" + 0.030*"knowledge" + 0.016*"und" + 0.015*"management" + 0.014*"analysis" + 0.013*"integration" + 0.013*"approach" + 0.013*"change"
#
# Score: 0.008548857644200325
# Topic: 2
# 0.033*"approach" + 0.031*"model" + 0.030*"learning" + 0.025*"modeling" + 0.019*"analysis" + 0.015*"pattern" + 0.015*"data" + 0.014*"planning" + 0.014*"prediction" + 0.013*"machine"
#
# Score: 0.008548857644200325
# Topic: 7
# 0.042*"software" + 0.040*"design" + 0.033*"system" + 0.028*"development" + 0.019*"virtual" + 0.018*"engineering" + 0.018*"environment" + 0.017*"robot" + 0.017*"digital" + 0.014*"review"
#
# Score: 0.008548857644200325
# Topic: 11
# 0.044*"study" + 0.023*"case" + 0.020*"technology" + 0.019*"research" + 0.017*"language" + 0.015*"information" + 0.014*"issue" + 0.014*"special" + 0.013*"science" + 0.012*"theory"

# %%
test_document_topics = lda_model_bow.get_document_topics(bow_corpus[random_doc_id], minimum_probability=0)

# %%
test_document_topics
# Out:
# [(0, 0.012530396),
#  (1, 0.13756263),
#  (2, 0.13767186),
#  (3, 0.13778837),
#  (4, 0.012529179),
#  (5, 0.13780819),
#  (6, 0.012531596),
#  (7, 0.2623018),
#  (8, 0.012529179),
#  (9, 0.13674678)]

# %%
sorted(lda_model_bow.get_document_topics(bow_corpus[random_doc_id]), key=lambda tup: -1*tup[1])[0]
# Out:
# (7, 0.2623018)

# %% [markdown]
# ## Get title topics and author-count

# %%
def generate_title_topics_and_author_count(filename, display_count):
    line_count = 0
    dashboard_output_format = []
    with open(filename, encoding="UTF", newline='') as csvfile:
        articles = csv.reader(csvfile, delimiter=',')
        
        for row in articles:
            if row:
                if line_count > 0:
                    article_id = int(row[0])
                    year = 0 if row[-1] == '' else int(row[-1])
                    title = row[-6].translate(str.maketrans('', '', ",.;:'?!/`()[]{}<>\\"))
                    try:
                        #title_bow = bow_corpus[article_id]                        
                        title_bow = title_terms_dict.doc2bow(title_terms_map[title])
                    except:
                        print(title)
                        continue
                    title_top_topic_id = sorted(lda_model_bow.get_document_topics(title_bow), key=lambda tup: -1*tup[1])[0][0]
                    title_top_topic_id = labels_merged_map[title_top_topic_id]
                    dashboard_output_format.append([year, title, title_top_topic_id, row[1].count('|')+1])

                    if line_count < display_count:
                        print(row)
                        print(dashboard_output_format[article_id])
                else:
                    print(row, end='\n----------------------------------------------------------------------------------------\n')
                line_count += 1
    
    print("No. of Lines:", line_count)
    
    return dashboard_output_format

# %%
dashboard_output_format = generate_title_topics_and_author_count("./data/dblp_article.csv", 5)
# Out:
# ['id', 'author', 'author-aux', 'author-orcid', 'booktitle', 'cdate', 'cdrom', 'cite', 'cite-label', 'crossref', 'editor', 'editor-orcid', 'ee', 'ee-type', 'i', 'journal', 'key', 'mdate', 'month', 'note', 'note-type', 'number', 'pages', 'publisher', 'publtype', 'sub', 'sup', 'title', 'title-bibtex', 'tt', 'url', 'volume', 'year']
# ----------------------------------------------------------------------------------------
# ['0', 'Sanjeev Saxena', '', '', '', '', '', '', '', '', '', '', 'https://doi.org/10.1007/BF03036466', '', '', 'Acta Inf.', 'journals/acta/Saxena96', '2017-05-28', '', '', '', '7', '607-619', '', '', '', '', 'Parallel Integer Sorting and Simulation Amongst CRCW Models.', '', '', 'db/journals/acta/acta33.html#Saxena96', '33', '1996']
# [1996, 'Parallel Integer Sorting and Simulation Amongst CRCW Models', 0, 1]
# ['1', 'Hans Ulrich Simon', '', '', '', '', '', '', '', '', '', '', 'https://doi.org/10.1007/BF01257084', '', '', 'Acta Inf.', 'journals/acta/Simon83', '2017-05-28', '', '', '', '', '227-248', '', '', '', '', 'Pattern Matching in Trees and Nets.', '', '', 'db/journals/acta/acta20.html#Simon83', '20', '1983']
# [1983, 'Pattern Matching in Trees and Nets', 6, 1]
# ['2', 'Nathan Goodman|Oded Shmueli', '', '', '', '', '', '', '', '', '', '', 'https://doi.org/10.1007/BF00289414', '', '', 'Acta Inf.', 'journals/acta/GoodmanS83', '2017-05-28', '', '', '', '', '171-178', '', '', '', '', 'NP-complete Problems Simplified on Tree Schemas.', '', '', 'db/journals/acta/acta20.html#GoodmanS83', '20', '1983']
# [1983, 'NP-complete Problems Simplified on Tree Schemas', 4, 2]
# ['3', 'Norbert Blum', '', '', '', '', '', '', '', '', '', '', 'https://doi.org/10.1007/BF00264161', '', '', 'Acta Inf.', 'journals/acta/Blum82', '2017-05-28', '', '', '', '', '425-433', '', '', '', '', 'On the Power of Chain Rules in Context Free Grammars.', '', '', 'db/journals/acta/acta17.html#Blum82', '17', '1982']
# [1982, 'On the Power of Chain Rules in Context Free Grammars', 10, 1]
# No. of Lines: 2008468

# %%
print(len(dashboard_output_format))
dashboard_output_format[:7]
# Out:
# 2008467
# [[1996, 'Parallel Integer Sorting and Simulation Amongst CRCW Models', 0, 1],
#  [1983, 'Pattern Matching in Trees and Nets', 6, 1],
#  [1983, 'NP-complete Problems Simplified on Tree Schemas', 4, 2],
#  [1982, 'On the Power of Chain Rules in Context Free Grammars', 10, 1],
#  [1977,
#   'Schnelle Multiplikation von Polynomen über Körpern der Charakteristik 2',
#   10,
#   1],
#  [2011, 'A characterization of rational D0L power series', 3, 1],
#  [1987, 'The Derivation of Systolic Implementations of Programs', 0, 2]]

# %%
sorted(dashboard_output_format, key=lambda lst: -1*lst[-1])
# Out:
# [[2015,
#   'The IceProd framework Distributed data processing for the IceCube neutrino observatory',
#   1,
#   287],
#  [2013,
#   'The IceProd Framework Distributed Data Processing for the IceCube Neutrino Observatory',
#   1,
#   287],
#  [2014, 'A promoter-level mammalian expression atlas', 1, 263],
#  [2006,
#   'Length Sensing and Control in the Virgo Gravitational Wave Interferometer',
#   6,
#   119],
#  [2018,
#   'Machine Learning in High Energy Physics Community White Paper',
#   9,
#   118],
#  [2016,
#   'Theano A Python framework for fast computation of mathematical expressions',
#   8,
#   112],
#  [2015,
#   'The BioMart community portal an innovative alternative to large centralized data repositories',
#   7,
#   105],
#  [2014,
#   'Finding needles in haystacks linking scientific names reference specimens and molecular data for Fungi',
#   8,
#   101],
#  [2015,
#   'New vegetation type map of India prepared using satellite remote sensing Comparison with global vegetation maps and utilities',
#   0,
#   99],
#  [2015, 'Integrative analysis of 111 reference human epigenomes Open', 9, 96],
#  [2015,
#   'EVpedia a community web portal for extracellular vesicles research',
#   9,
#   95],
#  [2017,
#   'Automatic identification of variables in epidemiological datasets using logic regression',
#   2,
#   92],
#  [2009,
#   'Interoperation of world-wide production e-Science infrastructures',
#   6,
#   86],
#  [2010, 'Distributed Analysis in CMS', 1, 79],
#  [2014, 'Comparative analysis of metazoan chromatin organization Open', 3, 78],
#  [2005,
#   'The Biomolecular Interaction Network Database and related tools 2005 update',
#   6,
#   75],
#  [2019,
#   'An Empirical Comparison of Meta- and Mega-Analysis With Data From the ENIGMA Obsessive-Compulsive Disorder Working Group',
#   0,
#   75],
#  [2016, 'A genomic history of Aboriginal Australia', 3, 75],
#  [2017,
#   'In-Datacenter Performance Analysis of a Tensor Processing Unit',
#   8,
#   74],
#  [2019,
#   'Linked Open Data Validity - A Technical Report from ISWS 2018',
#   9,
#   71],
#  [1999, 'Status of the BNL muon g-2 experiment', 9, 71],
#  [2017,
#   'Coordinated regulation of acid resistance in Escherichia coli',
#   4,
#   69],
#  [2019,
#   'Expansion of the Human Phenotype Ontology HPO knowledge base and resources',
#   1,
#   69],
#  [2016,
#   'Tools and data services registry a community effort to document bioinformatics resources',
#   5,
#   69],
#  [2015,
#   'The Multimodal Brain Tumor Image Segmentation Benchmark BRATS',
#   1,
#   68],
#  [2019, 'Ensembl 2019', 8, 68],
#  [2015, 'The Murchison Widefield Array Correlator', 1, 67],
#  [2014,
#   'Proceedings of the second "international Traveling Workshop on Interactions between Sparse models and Technology" iTWIST14',
#   3,
#   67],
#  [2011, 'The International Exascale Software Project roadmap', 0, 65],
#  [2015,
#   'Genome Modeling System A Knowledge Management Platform for Genomics',
#   1,
#   64],
#  [2002, 'Humanoid Robots in Waseda University-Hadaly-2 and WABIAN', 7, 64],
#  [2011,
#   'BioMart Central Portal an open database network for the biological community',
#   5,
#   61],
#  [2016,
#   'Proceedings of the third "international Traveling Workshop on Interactions between Sparse models and Technology" iTWIST16',
#   3,
#   60],
#  [2019,
#   'The FAIR Funder pilot programme to make it easy for funders to require and for grantees to produce FAIR Data',
#   2,
#   60],
#  [2017, 'Big GABA Edited MR spectroscopy at 24 research sites', 3, 60],
#  [2008, 'Ensembl 2008', 4, 59],
#  [2017, 'The Human Phenotype Ontology in 2017', 1, 59],
#  [2018,
#   'Benchmarking the HLA typing performance of Polysolver and Optitype in 50 Danish parental trios',
#   3,
#   59],
#  [2019, 'The Liver Tumor Segmentation Benchmark LiTS', 8, 59],
#  [2009, 'Ensembl 2009', 6, 58],
#  [2007, 'Ensembl 2007', 8, 58],
#  [2019,
#   'Lingvo a Modular and Scalable Framework for Sequence-to-Sequence Modeling',
#   7,
#   58],
#  [2019,
#   'Editorial TVLSI Positioning - Continuing and Accelerating an Upward Trajectory',
#   8,
#   57],
#  [2011,
#   'The 2nd DBCLS BioHackathon interoperable bioinformatics Web services for integrated applications',
#   7,
#   57],
#  [2010,
#   'The DBCLS BioHackathon standardization and interoperability for bioinformatics web services and workflows',
#   3,
#   57],
#  [2012, 'Ensembl 2012', 2, 57],
#  [2010, 'Ensembls 10th year', 5, 57],
#  [2018, 'Ensembl 2018', 7, 57],
#  [2018,
#   'Nanoseconds Timing System Based on IEEE 1588 FPGA Implementation',
#   3,
#   57],
#  [2016,
#   'Toward Community Standards and Software for Whole-Cell Modeling',
#   9,
#   57],
#  [2017,
#   'Open Targets a platform for therapeutic target identification and validation',
#   4,
#   56],
#  [2016, 'Overview of the interactive task in BioCreative V', 4, 56],
#  [2016, 'Power estimation for non-standardized multisite studies', 1, 56],
#  [2016, 'Recent developments in the ABINIT software package', 9, 55],
#  [2016,
#   'Reference sequence RefSeq database at NCBI current status taxonomic expansion and functional annotation',
#   8,
#   55],
#  [2019, 'GENCODE reference annotation for the human and mouse genomes', 8, 55],
#  [2012, 'The UniProt-GO Annotation database in 2011', 1, 55],
#  [2013, 'Ensembl 2013', 3, 55],
#  [2014,
#   'Standing Together for Reproducibility in Large-Scale Computing Report on reproducibility@XSEDE',
#   4,
#   55],
#  [2011,
#   'Evaluation of Registration Methods on Thoracic CT The EMPIRE10 Challenge',
#   0,
#   54],
#  [2015, 'On Optimizing Human-Machine Task Assignments', 2, 54],
#  [2015,
#   'The CHEMDNER corpus of chemicals and drugs and its annotation principles',
#   8,
#   53],
#  [2018,
#   'The Surprising Creativity of Digital Evolution A Collection of Anecdotes from the Evolutionary Computation and Artificial Life Research Communities',
#   5,
#   53],
#  [2018,
#   'INDIGO-DataCloud a Platform to Facilitate Seamless Access to E-Infrastructures',
#   9,
#   53],
#  [2001,
#   'Blue Gene A vision for protein science using a petaflop supercomputer',
#   9,
#   52],
#  [2011, 'Ensembl 2011', 1, 52],
#  [2005, 'Ensembl 2005', 1, 52],
#  [2014, 'Ensembl 2014', 3, 52],
#  [2018,
#   'Automatic segmentation of the spinal cord and intramedullary multiple sclerosis lesions with convolutional neural networks',
#   5,
#   52],
#  [2019, 'WIDER Face and Pedestrian Challenge 2018 Methods and Results', 4, 52],
#  [2017,
#   'Discovery and replication of SNP-SNP interactions for quantitative lipid traits in over 60000 individuals',
#   7,
#   52],
#  [2018,
#   'AgBioData consortium recommendations for sustainable genomics and genetics databases for agriculture',
#   2,
#   52],
#  [2006, 'Ensembl 2006', 3, 51],
#  [2018,
#   'Identifying the Best Machine Learning Algorithms for Brain Tumor Segmentation Progression Assessment and Overall Survival Prediction in the BRATS Challenge',
#   1,
#   51],
#  [1998, 'The MONET New Jersey network demonstration', 8, 51],
#  [2018,
#   'Worldwide Protein Data Bank biocuration supporting open access to high-quality 3D structural biology data',
#   3,
#   51],
#  [2009,
#   'Comparison and Evaluation of Methods for Liver Segmentation From CT Datasets',
#   0,
#   50],
#  [2008, 'Special Issue The First Provenance Challenge', 3, 50],
#  [2012,
#   'InterPro in 2011 new developments in the family and domain prediction database',
#   8,
#   50],
#  [2017, 'Ensembl 2017', 1, 50],
#  [2019,
#   'Artificial Intelligence for Prosthetics - challenge solutions',
#   1,
#   50],
#  [2012,
#   'Status Report of the DPHEP Study Group Towards a Global Effort for Sustainable Data Preservation in High Energy Physics',
#   1,
#   50],
#  [2017,
#   'Large-Scale 3D Shape Reconstruction and Segmentation from ShapeNet Core55',
#   6,
#   50],
#  [2000, 'The Distributed ASCI Supercomputer Project', 1, 49],
#  [2018, 'Meet-U Educating through research immersion', 3, 49],
#  [2015, 'Ensembl 2015', 9, 49],
#  [2015,
#   'Development of Decadal 1985-1995-2005 Land Use and Land Cover Database for India',
#   8,
#   48],
#  [2016,
#   'Multi-wheat-model ensemble responses to interannual climate variability',
#   3,
#   48],
#  [2006,
#   'The Earth observing system microwave limb sounder EOS MLS on the aura Satellite',
#   7,
#   48],
#  [2004, 'Ensembl 2004', 8, 48],
#  [2018,
#   'PIRM Challenge on Perceptual Image Enhancement on Smartphones Report',
#   7,
#   48],
#  [2019, 'The ISTI Rapid Response on Exploring Cloud Computing 2018', 1, 48],
#  [2019,
#   'Deep Learning for Multi-Messenger Astrophysics A Gateway for Discovery in the Big Data Era',
#   8,
#   48],
#  [2004,
#   'The Helmholtz Network for Bioinformatics an integrative web portal for bioinformatics resources',
#   0,
#   48],
#  [2009, 'The Murchison Widefield Array Design Overview', 4, 48],
#  [2019,
#   'Improved annotation of the insect vector of citrus greening disease biocuration by a diverse genomics community',
#   9,
#   48],
#  [2017,
#   'Improved annotation of the insect vector of citrus greening disease biocuration by a diverse genomics community',
#   9,
#   48],
#  [2014,
#   'Update of the Binoth Les Houches Accord for a standard interface between Monte Carlo tools and one-loop programs',
#   6,
#   47],
#  [2014,
#   'The Human Phenotype Ontology project linking molecular biology and disease through phenotype data',
#   8,
#   47],
#  [2016, 'Ensembl 2016', 7, 47],
#  [2017,
#   'InterPro in 2017 - beyond protein family and domain annotations',
#   1,
#   47],
#  [2015, 'Valkyrie NASAs First Bipedal Humanoid Robot', 7, 47],
#  [2016,
#   'A 27 mWChannel 48-1000 MHz Direct Sampling Full-Band Cable Receiver',
#   3,
#   47],
#  [2014,
#   'The Zebrafish GenomeWiki a crowdsourcing approach to connect the long tail for zebrafish gene annotation',
#   1,
#   47],
#  [2014, 'The contribution of ', 6, 47],
#  [2014,
#   'APSIM - Evolution towards a new generation of agricultural systems simulation',
#   3,
#   46],
#  [2018,
#   'Ensembl Genomes 2018 an integrated omics infrastructure for non-vertebrate species',
#   1,
#   46],
#  [2018, 'The SysteMHC Atlas project', 0, 46],
#  [2009,
#   'The Allen Telescope Array The First Widefield Panchromatic Snapshot Radio Camera for Radio Astronomy and SETI',
#   1,
#   46],
#  [2007, 'The Blue GeneL Supercomputer A Hardware and Software Story', 8, 46],
#  [2017, 'Editorial', 4, 45],
#  [2018,
#   'Satellite and In Situ Observations for Advancing Global Earth Surface Modelling A Review',
#   7,
#   45],
#  [2007, 'New developments in the InterPro database', 8, 45],
#  [2017, 'Sustainable computational science the ReScience initiative', 3, 45],
#  [2017, 'Sustainable computational science the ReScience initiative', 3, 45],
#  [2013, 'Multiphysics simulations Challenges and opportunities', 3, 45],
#  [2016,
#   'Longitudinal reproducibility of default-mode network connectivity in healthy elderly participants A multicentric resting-state fMRI study',
#   1,
#   45],
#  [2013, 'The ', 0, 45],
#  [2014,
#   'Towards an Operational SAR-Based Rice Monitoring System in Asia Examples from 13 Demonstration Sites across Asia in the RIICE Project',
#   4,
#   44],
#  [2017, 'In Memoriam Gunter Menz', 2, 44],
#  [2010,
#   'TriTrypDB a functional genomic resource for the Trypanosomatidae',
#   3,
#   44],
#  [2004,
#   'GermOnline a cross-species community knowledgebase on germ cell differentiation',
#   9,
#   44],
#  [2004,
#   'Autonomic Management of Large Clusters and Their Integration into the Grid',
#   0,
#   44],
#  [2016,
#   'The strategic impact of META-NET on the regional national and international level',
#   7,
#   44],
#  [2018,
#   'Serving DNNs in Real Time at Datacenter Scale with Project Brainwave',
#   0,
#   43],
#  [2018,
#   'SiCILIA - Silicon Carbide Detectors for Intense Luminosity Investigations and Applications',
#   6,
#   43],
#  [2006,
#   'Reports on the Twenty-First National Conference on Artificial Intelligence AAAI-06 Workshop Program',
#   7,
#   43],
#  [2005, 'GeneFarm structural and functional annotation of ', 3, 43],
#  [2007, 'PATRIC The VBI PathoSystems Resource Integration Center', 1, 43],
#  [2012,
#   'Database resources of the National Center for Biotechnology Information',
#   1,
#   43],
#  [2014,
#   'Current status and new features of the Consensus Coding Sequence database',
#   8,
#   43],
#  [2003,
#   'The systems biology markup language SBML a medium for representation and exchange of biochemical network models',
#   8,
#   43],
#  [2019,
#   'Multiomics modeling of the immunome transcriptome microbiome proteome and metabolome adaptations during human pregnancy',
#   7,
#   43],
#  [2014, 'Addendum Enterotypes of the human gut microbiome', 9, 43],
#  [2014,
#   'CFEnetwork The Annals of Computational and Financial Econometrics 2nd Issue',
#   3,
#   42],
#  [2019,
#   'InterPro in 2019 improving coverage classification and access to protein sequence annotations',
#   8,
#   42],
#  [2011,
#   'Database resources of the National Center for Biotechnology Information',
#   1,
#   42],
#  [2006, 'Human protein reference database - 2006 update', 6, 42],
#  [2008,
#   'Autonomous driving in urban environments Boss and the Urban Challenge',
#   5,
#   42],
#  [2017,
#   'INDIGO-DataCloud A data and computing platform to facilitate seamless access to e-infrastructures',
#   1,
#   42],
#  [2011, 'Information technology for healthcare transformation', 0, 42],
#  [2017,
#   'SNP interaction pattern identifier SIPI an intensive search for SNP-SNP interaction patterns',
#   7,
#   42],
#  [2012, 'A 151-mm', 0, 42],
#  [2010,
#   'Learning by creating and exchanging objects The SCY experience',
#   8,
#   42],
#  [2008, 'BlueGeneL applications Parallelism On a Massive Scale', 0, 42],
#  [2006,
#   'The global lambda visualization facility An international ultra-high-definition wide-area visualization collaboratory',
#   6,
#   41],
#  [2015,
#   'TrypanoCyc a community-led biochemical pathways database for ',
#   8,
#   41],
#  [2018, '2018 Low-Power Image Recognition Challenge', 2, 41],
#  [2013,
#   'An overview of the BioCreative 2012 Workshop Track III interactive text mining task',
#   7,
#   41],
#  [2014,
#   'Multisite longitudinal reliability of tract-based spatial statistics in diffusion tensor imaging of healthy elderly subjects',
#   8,
#   41],
#  [2017,
#   'Assessing computational genomics skills Our experience in the H3ABioNet African bioinformatics network',
#   5,
#   40],
#  [2005, 'InterPro progress and status in 2005', 9, 40],
#  [2007, 'HMDB the Human Metabolome Database', 8, 40],
#  [2010,
#   'Database resources of the National Center for Biotechnology Information',
#   1,
#   40],
#  [2019,
#   'RCSB Protein Data Bank biological macromolecular structures enabling research and education in fundamental biology biomedicine biotechnology and energy',
#   0,
#   40],
#  [2017,
#   'DisProt 70 a major update of the database of disordered proteins',
#   8,
#   40],
#  [2016,
#   'TensorFlow Large-Scale Machine Learning on Heterogeneous Distributed Systems',
#   8,
#   40],
#  [2017,
#   'D32 SPEED-5G enhanced functional and system architecture scenarios and performance evaluation metrics',
#   1,
#   40],
#  [2007,
#   'Construction of an open-access database that integrates cross-reference information from the transcriptome and proteome of immune cells',
#   0,
#   40],
#  [2014,
#   'Comparative analysis of regulatory information and circuits across distant species Open',
#   1,
#   40],
#  [2018,
#   'Evaluation of Single-Chip Real-Time Tomographic Data Processing on FPGA SoC Devices',
#   1,
#   39],
#  [2007, 'AAAI-07 Workshop Reports', 9, 39],
#  [2002,
#   'What Every Business Student Needs to Know About Information Systems',
#   3,
#   39],
#  [2012, 'WormBase 2012 more genomes more data new website', 9, 39],
#  [2018,
#   'Gramene 2018 unifying comparative genomics and pathway resources for plant research',
#   5,
#   39],
#  [2018,
#   'ANISEED 2017 extending the integrated ascidian database to the exploration and evolutionary comparison of genome-scale datasets',
#   1,
#   39],
#  [2019,
#   'BPG Seamless automated and interactive visualization of scientific data',
#   8,
#   39],
#  [2016, 'Extreme Scale-out SuperMUC Phase 2 - lessons learned', 3, 39],
#  [2019,
#   'A 16-Gb 18-Gbspin GDDR6 DRAM With Per-Bit Trainable Single-Ended DFE and PLL-Less Clocking',
#   9,
#   39],
#  [2009,
#   'Collaborative annotation of genes and proteins between UniProtKBSwiss-Prot and dictyBase',
#   6,
#   39],
#  [2018, 'Big data and extreme-scale computing', 8, 39],
#  [2016,
#   'Active medulloblastoma enhancers reveal subgroup-specific cellular origins',
#   0,
#   39],
#  [2016,
#   'Big Data Analytics for Earth Sciences the EarthServer approach',
#   8,
#   38],
#  [2016, 'Ensembl Genomes 2016 more genomes more complexity', 9, 38],
#  [2011,
#   'Towards BioDBcore a community-defined information specification for biological databases',
#   8,
#   38],
#  [2009, 'InterPro the integrative protein signature database', 9, 38],
#  [2008, 'UTGBmedaka genomic resource database for medaka biology', 8, 38],
#  [2009, 'HMDB a knowledgebase for the human metabolome', 1, 38],
#  [2018,
#   'Proceedings of the Workshop on Social Robots in Therapy Focusing on Autonomy and Ethical Challenges',
#   0,
#   38],
#  [2018,
#   'Is the winner really the best A critical analysis of common research practice in biomedical image analysis competitions',
#   3,
#   38],
#  [2015,
#   'Learning from FITS Limitations in use in modern astronomical research',
#   3,
#   38],
#  [2013,
#   'Standardized evaluation framework for evaluating coronary artery stenosis detection stenosis quantification and lumen segmentation algorithms in computed tomography angiography',
#   9,
#   38],
#  [2018,
#   'Building a cognitive platform for the managed IT services lifecycle',
#   3,
#   38],
#  [2018,
#   'AA9int SNP interaction pattern search using non-hierarchical additive model set',
#   0,
#   38],
#  [2016,
#   'Molcas 8 New capabilities for multiconfigurational quantum chemical calculations across the periodic table',
#   0,
#   38],
#  [2011, 'A Quad-Band GSMGPRSEDGE SoC in 65 nm CMOS', 3, 38],
#  [2011,
#   'Towards BioDBcore a community-defined information specification for biological databases',
#   8,
#   38],
#  [2011,
#   'Assessment of NER solutions against the first and second CALBC Silver Standard Corpus',
#   9,
#   37],
#  [2018,
#   'Deep Learning Techniques for Automatic MRI Cardiac Multi-Structures Segmentation and Diagnosis Is the Problem Solved',
#   4,
#   37],
#  [2009,
#   'The Long-Term Ecological Research community metadata standardisation project a progress report',
#   9,
#   37],
#  [2009, 'AAAI 2008 Workshop Reports', 9, 37],
#  [2017,
#   'Reports of the Workshops of the Thirty-First AAAI Conference on Artificial Intelligence',
#   7,
#   37],
#  [2009,
#   'A Proposal for a Coordinated Effort for the Determination of Brainwide Neuroanatomical Connectivity in Model Organisms at a Mesoscopic Scale',
#   5,
#   37],
#  [2017,
#   'Network topology of NaV17 mutations in sodium channel-related painful disorders',
#   1,
#   37],
#  [2003,
#   'The InterPro Database 2003 brings increased coverage and new features',
#   8,
#   37],
#  [2018,
#   'Consensus coding sequence CCDS database a standardized set of human and mouse protein-coding regions supported by expert curation',
#   8,
#   37],
#  [2010, 'Optimization of PlanckLFI on--board data handling', 8, 37],
#  [2012,
#   'An Ensemble Architecture for Learning Complex Problem-Solving Techniques from Demonstration',
#   8,
#   37],
#  [2000, 'A Recurrence Generating Multiples of Primes 10655', 6, 37],
#  [2013,
#   'Swarmanoid A Novel Concept for the Study of Heterogeneous Robotic Swarms',
#   8,
#   37],
#  [2011,
#   'Design Issues and Considerations for Low-Cost 3-D TSV IC Technology',
#   3,
#   37],
#  [2012, 'Global landscape of HIV-human protein complexes', 4, 37],
#  [2018,
#   'GNSS Transpolar Earth Reflectometry exploriNg System G-TERN Mission Concept',
#   8,
#   36],
#  [2018,
#   'Statistical Shape Modeling of the Left Ventricle Myocardial Infarct Classification Challenge',
#   1,
#   36],
#  [2015,
#   'The EnMAP Spaceborne Imaging Spectroscopy Mission for Earth Observation',
#   7,
#   36],
#  [2019,
#   'From Detection of Individual Metastases to Classification of Lymph Node Status at the Patient Level The CAMELYON17 Challenge',
#   0,
#   36],
#  [2017,
#   'A novel approach for selecting combination clinical markers of pathology applied to a large retrospective cohort of surgically resected pancreatic cysts',
#   0,
#   36],
#  [2003, 'Ensembl 2002 accommodating comparative genomics', 5, 36],
#  [2018,
#   'miRTarBase update 2018 a resource for experimentally validated microRNA-target interactions',
#   7,
#   36],
#  [2015,
#   'The InterPro protein families database the classification resource after 15 years',
#   5,
#   36],
#  [2008,
#   'Priorities for nucleotide trace sequence and annotation data capture at the Ensembl Trace Archive and the EMBL Nucleotide Sequence Database',
#   8,
#   36],
#  [2016,
#   'CATI A Large Distributed Infrastructure for the Neuroimaging of Cohorts',
#   1,
#   36],
#  [2018, 'BACH Grand Challenge on Breast Cancer Histology Images', 1, 36],
#  [2012, 'WeNMR Structural Biology on the Grid', 0, 36],
#  [2015,
#   'Enhancing disease surveillance with novel data streams challenges and opportunities',
#   8,
#   36],
#  [2003,
#   'Challenges in information retrieval and language modeling report of a workshop held at the center for intelligent information retrieval University of Massachusetts Amherst September 2002',
#   1,
#   36],
#  [2000,
#   'Q-Chem 20 a high-performance ab initio electronic structure program package',
#   8,
#   36],
#  [2014, 'A 1307-mm', 0, 36],
#  [2017,
#   'MGIS managing banana Musa spp genetic resources information and high-throughput genotyping data',
#   1,
#   36],
#  [2014,
#   'The ctenophore genome and the evolutionary origins of neural systems Open',
#   9,
#   36],
#  [2018, 'F1 Query Declarative Querying at Scale', 6, 36],
#  [2017,
#   'Downstream Services for Rice Crop Monitoring in Europe From Regional to Local Scale',
#   3,
#   35],
#  [2012,
#   'Review of the CALIMAS Team Contributions to European Space Agencys Soil Moisture and Ocean Salinity Mission Calibration and Validation',
#   7,
#   35],
#  [2016, 'Reports of the 2016 AAAI Workshop Program', 9, 35],
#  [2018,
#   'Shared activity patterns arising at genetic susceptibility loci reveal underlying genomic and cellular architecture of human disease',
#   3,
#   35],
#  [2015, 'A multi-omic analysis of human naïve CD4+ T cells', 1, 35],
#  [2002, 'The Ensembl genome database project', 8, 35],
#  [2008,
#   'Evola Ortholog database of all human genes in H-InvDB with manual curation of phylogenetic trees',
#   6,
#   35],
#  [2014,
#   'The MIntAct project - IntAct as a common curation platform for 11 molecular interaction databases',
#   7,
#   35],
#  [2009, 'QPACE - a QCD parallel computer based on Cell processors', 3, 35],
#  [2017,
#   'Pattern representation and recognition with accelerated analog neuromorphic systems',
#   0,
#   35],
#  [2013, 'iAnn an event sharing platform for the life sciences', 8, 35],
#  [2013,
#   'Imputation of coding variants in African Americans better performance using data from the exome sequencing project',
#   0,
#   35],
#  [2009, 'CHARMM The biomolecular simulation program', 8, 35],
#  [2012,
#   'Nanoinformatics developing new computing applications for nanomedicine',
#   4,
#   35],
#  [2016,
#   'BioCreative V BioC track overview collaborative biocurator assistant task for BioGRID',
#   4,
#   35],
#  [2016,
#   'The Global Genome Biodiversity Network GGBN Data Standard specification',
#   8,
#   35],
#  [2013,
#   'A compendium of RNA-binding motifs for decoding gene regulation',
#   3,
#   35],
#  [1993,
#   'DRUMS Defeasible Reasoning and Uncertainty Management Systems',
#   1,
#   34],
#  [2010, 'The next-generation ARC middleware', 5, 34],
#  [2011,
#   'A comprehensive workflow for general-purpose neural modeling with highly configurable neuromorphic hardware systems',
#   4,
#   34],
#  [2010,
#   'Collaborative development of predictive toxicology applications',
#   6,
#   34],
#  [2015, 'Reports of the AAAI 2014 Conference Workshops', 9, 34],
#  [2015,
#   ' Comprehensive Sieve Analysis of Breakthrough HIV-1 Sequences in the RV144 Vaccine Efficacy Trial',
#   8,
#   34],
#  [2016, 'Assessment of the SMAP Passive Soil Moisture Product', 6, 34],
#  [2006, 'EMBL Nucleotide Sequence Database developments in 2005', 8, 34],
#  [2009,
#   'ArrayExpress update - from an archive of functional genomics experiments to the atlas of gene expression',
#   8,
#   34],
#  [2007, 'WormBase new content and better access', 3, 34],
#  [2007, 'EMBL Nucleotide Sequence Database in 2006', 8, 34],
#  [2014, 'LocTree3 prediction of localization', 1, 34],
#  [2016, 'WormBase 2016 expanding to enable helminth genomic research', 3, 34],
#  [2010, 'Genomic analysis of a rare human tumor', 1, 34],
#  [2015,
#   'Deep Speech 2 End-to-End Speech Recognition in English and Mandarin',
#   2,
#   34],
#  [2017,
#   'Proceedings of Workshop AEW10 Concepts in Information Theory and Communications',
#   1,
#   34],
#  [2019,
#   'Evaluation of Algorithms for Multi-Modality Whole Heart Segmentation An Open-Access Grand Challenge',
#   0,
#   34],
#  [2018,
#   'Scalable and accurate deep learning for electronic health records',
#   8,
#   34],
#  [2017,
#   'Cyberinfrastructure for Open Science at the Montreal Neurological Institute',
#   9,
#   34],
#  [2012,
#   'A Tri-Modal 20-GbpsLink DifferentialDDR3GDDR5 Memory Interface',
#   4,
#   34],
#  [2016,
#   'Rewriting yeast central carbon metabolism for industrial isoprenoid production',
#   9,
#   34],
#  [2009,
#   'ABINIT First-principles approach to material and nanosystem properties',
#   2,
#   33],
#  [2018, 'A HardwareSoftware Stack for Heterogeneous Systems', 8, 33],
#  [2011,
#   'Online chemical modeling environment OCHEM web platform for data storage model development and publishing of chemical information',
#   1,
#   33],
#  [2013,
#   'The crosscutting impact of the AOSD Brazilian research community',
#   9,
#   33],
#  [2010,
#   'Transport Infrastructure Surveillance and Monitoring by Electromagnetic Sensing The ISTIMES Project',
#   6,
#   33],
#  [2014,
#   'The ITALK Project A Developmental Robotics Approach to the Study of Individual Social and Linguistic Learning',
#   0,
#   33],
#  [2012, 'Reports of the AAAI 2011 Conference Workshops', 1, 33],
#  [2017,
#   'Assessing electronic health record phenotypes against gold-standard diagnostic criteria for diabetes mellitus',
#   5,
#   33],
#  [2014, 'Ensembl Genomes 2013 scaling up access to genome-wide data', 9, 33],
#  [2008,
#   'Database resources of the National Center for Biotechnology Information',
#   1,
#   33],
#  [2009,
#   'Database resources of the National Center for Biotechnology Information',
#   1,
#   33],
#  [2008, 'WormBase 2007', 8, 33],
#  [2016,
#   'PDBe improved accessibility of macromolecular structure data from PDB and EMDB',
#   7,
#   33],
#  [2011, 'PDBe Protein Data Bank in Europe', 1, 33],
#  [2014,
#   'The International Mouse Phenotyping Consortium Web Portal a unified point of access for knockout mice and related phenotyping data',
#   8,
#   33],
#  [2010, 'NBRP databases databases of biological resources in Japan', 8, 33],
#  [2011, 'UKPMC a full text article resource for the life sciences', 6, 33],
#  [2014, 'WormBase 2014 new views of curated biology', 5, 33],
#  [2004,
#   'Human protein reference database as a discovery resource for proteomics',
#   1,
#   33],
#  [2018,
#   'Predicting breast tumor proliferation from whole-slide images the TUPAC16 challenge',
#   1,
#   33],
#  [2015,
#   'Status Report of the DPHEP Collaboration A Global Effort for Sustainable Data Preservation in High Energy Physics',
#   2,
#   33],
#  [2003, 'Run Control and Monitor System for the CMS Experiment', 6, 33],
#  [2016,
#   'Research and Education in Computational Science and Engineering',
#   3,
#   33],
#  [2016,
#   'The STRANDS Project Long-Term Autonomy in Everyday Environments',
#   0,
#   33],
#  [2018,
#   'Time-of-Flight Neutron Imaging on IMAT@ISIS A New User Facility for Materials Science',
#   9,
#   33],
#  [2017,
#   'The STRANDS Project Long-Term Autonomy in Everyday Environments',
#   0,
#   33],
#  [2010,
#   'Applicability Domains for Classification Problems Benchmarking of Distance to Models for Ames Mutagenicity Set',
#   8,
#   33],
#  [2010,
#   'A 16 GBs DDR2 128 Mb Chain FeRAM With Scalable Octal Bitline and Sensing Schemes',
#   3,
#   33],
#  [2016, 'Introduction of New Associate Editors', 8, 33],
#  [2012,
#   'Manual dexterity correlating with right lobule VI volume in right-handed 14-year-olds',
#   7,
#   33],
#  [1998,
#   'The EASI project-improving the effectiveness and quality of image-guided surgery',
#   7,
#   32],
#  [2017,
#   'Connecting Artificial Brains to Robots in a Comprehensive Simulation Framework The Neurorobotics Platform',
#   5,
#   32],
#  [2016,
#   'Development Production and Evaluation of Aerosol Climate Data Records from European Satellite Observations Aerosol_cci',
#   7,
#   32],
#  [2011,
#   'Online chemical modeling environment OCHEM web platform for data storage model development and publishing of chemical information',
#   1,
#   32],
#  [2014,
#   'Implementation of Ultrasonic Sensing for High Resolution Measurement of Binary Gas Mixture Fractions',
#   7,
#   32],
#  [2010, 'Reports of the AAAI 2010 Conference Workshops', 9, 32],
#  [2012,
#   'Viral Perturbations of Host Networks Reflect Disease Etiology',
#   1,
#   32],
#  [2018,
#   'A computational framework for complex disease stratification from multiple large-scale datasets',
#   6,
#   32],
#  [2013, 'The Protist Ribosomal Reference database PR', 8, 32],
#  [2017,
#   'IMGVR a database of cultured and uncultured DNA Viruses and retroviruses',
#   8,
#   32],
#  [2016,
#   'Gramene 2016 comparative plant genomics and pathway resources',
#   5,
#   32],
#  [2013, 'The UCSC Genome Browser database extensions and updates 2013', 9, 32],
#  [2005, 'The EMBL Nucleotide Sequence Database', 8, 32],
#  [2019,
#   'The Virtual Metabolic Human database integrating human and gut microbiome metabolism with nutrition and disease',
#   8,
#   32],
#  [2010, 'WormBase a comprehensive resource for nematode research', 9, 32],
#  [2012, 'PDBe Protein Data Bank in Europe', 1, 32],
#  [2006,
#   'Database resources of the National Center for Biotechnology Information',
#   1,
#   32],
#  [2003, 'Towards effective and rewarding data sharing', 8, 32],
#  [2018, 'Quantum Algorithm Implementations for Beginners', 6, 32],
#  [2019,
#   'Deep Neural Networks Improve Radiologists Performance in Breast Cancer Screening',
#   1,
#   32],
#  [2018,
#   'Deep Learning vs Human Graders for Classifying Severity Levels of Diabetic Retinopathy in a Real-World Nationwide Screening Program',
#   8,
#   32],
#  [2017,
#   'Blockchains for Business Process Management - Challenges and Opportunities',
#   1,
#   32],
#  [1996,
#   'High Speed High Capacity ATM Optical Switches for Future Telecommunication Transport Networks Invited Paper',
#   9,
#   32],
#  [2015, 'IBM z13 circuit design and methodology', 4, 32],
#  [2015,
#   'Active Memory Cube A processing-in-memory architecture for exascale systems',
#   4,
#   32],
#  [2013, 'Extreme Learning Machines', 6, 32],
#  [2004,
#   'HEP Applications and Their Experience with the Use of DataGrid Middleware',
#   9,
#   32],
#  [2013,
#   'RegaDB community-driven data management and analysis for infectious diseases',
#   8,
#   32],
#  [2000, 'The Variance of Logarithms 10690', 6, 32],
#  [2000, 'Tiling Rectangles with Trominoes 10641', 8, 32],
#  [2013, 'A 19 nm 1128 mm', 9, 32],
#  [2012, 'A 128-Gbslink Tri-Modal Single-Ended Memory Interface', 4, 32],
#  [2010,
#   'The Multiscenario Multienvironment BioSecure Multimodal Database BMDB',
#   8,
#   32],
#  [2016,
#   'Parallelizing Industrial Hard Real-Time Applications for the parMERASA Multicore',
#   8,
#   32],
#  [2011,
#   'Boys do it the right way Sex-dependent amygdala lateralization during face processing in adolescents',
#   1,
#   32],
#  [2018,
#   'Blockchains for Business Process Management - Challenges and Opportunities',
#   1,
#   32],
#  [2017,
#   '2016 IEEE Education Society Awards 2016 Frontiers in Education Conference Awards and Selected IEEE Awards',
#   8,
#   31],
#  [2013,
#   'Computational nuclear quantum many-body problem The UNEDF project',
#   3,
#   31],
#  [2016,
#   'GEROS-ISS GNSS REflectometry Radio Occultation and Scatterometry Onboard the International Space Station',
#   0,
#   31],
#  [2016,
#   'Standardized Evaluation System for Left Ventricular Segmentation Algorithms in 3D Echocardiography',
#   0,
#   31],
#  [2016,
#   'Human-Computer Interaction and International Public Policymaking A Framework for Understanding and Taking Future Actions',
#   6,
#   31],
#  [2019,
#   'Treatment recommendations to cancer patients in the context of FDA guidance for next generation sequencing',
#   3,
#   31],
#  [2005,
#   'A space-based end-to-end prototype geographic information network for lunar and planetary exploration and emergency response 2002 and 2003 field experiments',
#   1,
#   31],
#  [2002, 'AAAI 2002 Workshops', 1, 31],
#  [2005, 'WormBase a comprehensive data resource for ', 1, 31],
#  [2003,
#   'Neuroscience data and tool sharing - A legal and policy framework for neuroinformatics',
#   5,
#   31],
#  [2016,
#   'Validation comparison and combination of algorithms for automatic detection of pulmonary nodules in computed tomography images the LUNA16 challenge',
#   2,
#   31],
#  [2019,
#   'The Unconstrained Ear Recognition Challenge 2019 - ArXiv Version With Appendix',
#   2,
#   31],
#  [2016,
#   'Googles Neural Machine Translation System Bridging the Gap between Human and Machine Translation',
#   6,
#   31],
#  [2014,
#   'Making Bertha Drive - An Autonomous Journey on a Historic Route',
#   5,
#   31],
#  [2018,
#   'IBM z14 Enabling physical design in 14-nm technology for high-performance high-reliability microprocessors',
#   7,
#   31],
#  [2004,
#   'The DataGrid Workload Management System Challenges and Results',
#   1,
#   31],
#  [2002,
#   'InterPro An Integrated Documentation Resource for Protein Families Domains and Functional Sites',
#   0,
#   31],
#  [2016, 'Shape Retrieval of Non-rigid 3D Human Models', 5, 31],
#  [2017,
#   'M2DC - Modular Microserver DataCentre with heterogeneous hardware',
#   8,
#   31],
#  [2011, 'NetSlim high-confidence curated signaling maps', 9, 31],
#  [2013,
#   'Interacting with social networks of intelligent things and people in the world of gastronomy',
#   1,
#   31],
#  [2005, 'The INFN-Grid Testbed', 9, 30],
#  [2015,
#   'MRBrainS Challenge Online Evaluation Framework for Brain Image Segmentation in 3T MRI Scans',
#   1,
#   30],
#  [2014,
#   'BioHackathon series in 2011 and 2012 penetration of ontology and linked data in life science domains',
#   5,
#   30],
#  [2015,
#   'Building a Data Set over 12 Globally Distributed Sites to Support the Development of Agriculture Monitoring Applications with Sentinel-2',
#   8,
#   30],
#  [2017,
#   'MERLIN A French-German Space Lidar Mission Dedicated to Atmospheric Methane',
#   0,
#   30],
#  [2014, 'The Beckman Report on Database Research', 8, 30],
#  [2012, 'Extraction of Airways From CT EXACT09', 0, 30],
#  [2016, 'The Beckman report on database research', 8, 30],
#  [2017, 'Delivering Scalable Audio Experiences using AC-4', 5, 30],
#  [2016, 'Use of data mining at the Food and Drug Administration', 8, 30],
#  [2001,
#   'Application of Information Technology A Four-Dimensional Probabilistic Atlas of the Human Brain',
#   1,
#   30],
#  [2018,
#   'An integrated pan-European research infrastructure for validating smart grid systems',
#   0,
#   30],
#  [2006,
#   'Validation of global moderate-resolution LAI products a framework proposed within the CEOS land product validation subgroup',
#   6,
#   30],
#  [2015,
#   'BioAssay Research Database BARD chemical biology and probe-development enabled by structured metadata and result types',
#   0,
#   30],
#  [2004,
#   'WormBase a multi-species resource for nematode biology and genomics',
#   5,
#   30],
#  [2017,
#   'Pharos Collating protein information to shed light on the druggable genome',
#   9,
#   30],
#  [2007,
#   'Database resources of the National Center for Biotechnology Information',
#   1,
#   30],
#  [2014,
#   'Assembly information services in the European Nucleotide Archive',
#   5,
#   30],
#  [2006, 'WormBase better software richer content', 9, 30],
#  [2009, 'Human Protein Reference Database - 2009 update', 6, 30],
#  [2017, 'EuPathDB the eukaryotic pathogen genomics database resource', 8, 30],
#  [2018, 'WormBase 2017 molting into a new stage', 9, 30],
#  [2004, 'The EMBL Nucleotide Sequence Database', 8, 30],
#  [2006, 'Stanley The robot that won the DARPA Grand Challenge', 0, 30],
#  [2015, 'CHIMP the CMU Highly Intelligent Mobile Platform', 3, 30],
#  [2011,
#   'The Protein-Protein Interaction tasks of BioCreative III classificationranking of articles and linking bio-ontology concepts to full text',
#   7,
#   30],
#  [2018,
#   'Encompassing new use cases - level 30 of the HUPO-PSI format for molecular interactions',
#   9,
#   30],
#  [2014,
#   'Beating the news with EMBERS Forecasting Civil Unrest using Open Source Indicators',
#   5,
#   30],
#  [2003, 'The CMS Integration Grid Testbed', 4, 30],
#  [2016, 'SYSTRANs Pure Neural Machine Translation Systems', 5, 30],
#  [2019, 'Rucio - Scientific Data Management', 8, 30],
#  [2019, 'The ARIEL-CMU Systems for LoReHLT18', 4, 30],
#  [2003, 'DIRAC - Distributed Infrastructure with Remote Agent Control', 9, 30],
#  [2009,
#   'Standardized evaluation methodology and reference database for evaluating coronary artery centerline extraction algorithms',
#   6,
#   30],
#  [2011,
#   'Evaluation framework for carotid bifurcation lumen segmentation and stenosis grading',
#   0,
#   30],
#  [2014, 'A benchmark for comparison of cell tracking algorithms', 5, 30],
#  [2011,
#   'A 7 Gbspin 1 Gbit GDDR5 SDRAM With 25 ns Bank to Bank Active Time and No Bank Group Restriction',
#   1,
#   30],
#  [2018,
#   'A 60-GHz 144-Element Phased-Array Transceiver for Backhaul Application',
#   6,
#   30],
#  [2018, 'A 512-Gb 3-bCell 64-Stacked WL 3-D-NAND Flash Memory', 8, 30],
#  [2015,
#   'The 12-Core POWER8™ Processor With 76 Tbs IO Bandwidth Integrated Voltage Regulation and Resonant Clocking',
#   8,
#   30],
#  [2015,
#   'Three-Dimensional 128 Gb MLC Vertical nand Flash Memory With 24-WL Stacked Layers and 50 MBs High-Speed Programming',
#   1,
#   30],
#  [2010,
#   'Finding and sharing new approaches to registries of databases and services for the biomedical sciences',
#   8,
#   30],
#  [2014,
#   'Calibration of photomultipliers gain used in the J-PET detector',
#   7,
#   30],
#  [2014,
#   'Determination of the map of efficiency of the Jagiellonian Positron Emission Tomograph J-PET detector with the GATE package',
#   9,
#   30],
#  [2014,
#   'Simulations of γ quanta scattering in a single module of the J-PET detector',
#   3,
#   30],
#  [2014, 'List-mode reconstruction in 2D strip PET', 7, 30],
#  [2017, 'Variable structure robot control systems The RAPP approach', 8, 30],
#  [2014,
#   'Corrigendum to "Multi-site genetic analysis of diffusion images and voxelwise heritability analysis A pilot project of the ENIGMA-DTI working group" NeuroImage 81 2013 455-469',
#   0,
#   30],
#  [2013,
#   'Multi-site genetic analysis of diffusion images and voxelwise heritability analysis A pilot project of the ENIGMA-DTI working group',
#   1,
#   30],
#  [2015,
#   'Heritability of fractional anisotropy in human white matter A comparison of Human Connectome Project and ENIGMA-DTI data',
#   1,
#   30],
#  [2015,
#   'Assessing atrophy measurement techniques in dementia Results from the MIRIAD atrophy challenge',
#   1,
#   30],
#  [2014,
#   'Genetic influences on prefrontal activation during a verbal fluency task in adults A twin study based on multichannel near-infrared spectroscopy',
#   9,
#   30],
#  [2017,
#   'Creation and Interaction with Large-scale Domain-Specific Knowledge Bases',
#   6,
#   30],
#  [2018,
#   'Design and Optimization of a Polar Satellite Mission to Complement the Copernicus System',
#   8,
#   29],
#  [2018,
#   '2017 IEEE Education Society Awards 2017 Frontiers in Education Conference Awards and Selected IEEE Awards',
#   1,
#   29],
#  [2016, 'Demo hour', 3, 29],
#  [2016, 'Correction Dupuy E et al Comparison of XH', 4, 29],
#  [2016, 'Comparison of XH', 4, 29],
#  [2016,
#   'Cloud-Based Evaluation of Anatomical Structure Segmentation and Landmark Detection Algorithms VISCERAL Anatomy Benchmarks',
#   5,
#   29],
#  [2010,
#   '100 Gbs DQPSK field trial Live video transmission over an operating LambdaXtreme® network',
#   1,
#   29],
#  [2005, 'The Lowell database research self-assessment', 8, 29],
#  [2016,
#   'Evaluating the precision of eight spatial sampling schemes in estimating regional means of simulated yield for two crops',
#   7,
#   29],
#  [2003,
#   '3LB Construcción de una base de datos de árboles sintáctico semánticos',
#   6,
#   29],
#  [2018,
#   'Community-based benchmarking improves spike rate inference from two-photon calcium imaging data',
#   4,
#   29],
#  [2017,
#   'BIDS apps Improving ease of use accessibility and reproducibility of neuroimaging data analysis methods',
#   8,
#   29],
#  [2015,
#   'Desiderata for computable representations of electronic health records-driven phenotype algorithms',
#   0,
#   29],
#  [2008, 'Transmitter development for cellular integrated circuits', 0, 29],
#  [2005,
#   'Database resources of the National Center for Biotechnology Information',
#   1,
#   29],
#  [2010,
#   'ViralORFeome an integrated database to generate a versatile collection of viral ORFs',
#   7,
#   29],
#  [2007,
#   'The National Microbial Pathogen Database Resource NMPDR a genomics platform based on subsystem annotation',
#   1,
#   29],
#  [2012, 'ELM - the database of eukaryotic linear motifs', 8, 29],
#  [2008,
#   'ORegAnno an open-access community-driven resource for regulatory annotation',
#   1,
#   29],
#  [2015, 'The UCSC Genome Browser database 2015 update', 9, 29],
#  [2019,
#   'Cucurbit Genomics Database CuGenDB a central portal for comparative and functional genomics of cucurbit crops',
#   5,
#   29],
#  [2013, 'Facing growth in the European Nucleotide Archive', 8, 29],
#  [2003,
#   'STING Millennium a web-based suite of programs for comprehensive and simultaneous analysis of protein structure and sequence',
#   9,
#   29],
#  [2014, 'RefSeq an update on mammalian reference sequences', 6, 29],
#  [2017,
#   'The RCSB protein data bank integrative view of protein gene and 3D structural information',
#   5,
#   29],
#  [2010, 'Improvements to services at the European Nucleotide Archive', 3, 29],
#  [2012, 'The UCSC Genome Browser database extensions and updates 2011', 1, 29],
#  [2007,
#   'VectorBase a home for invertebrate vectors of human pathogens',
#   6,
#   29],
#  [2018,
#   'Data Portal for the Library of Integrated Network-based Cellular Signatures LINCS program integrated access to diverse large-scale cellular perturbation response data',
#   1,
#   29],
#  [2003, 'The Lowell Database Research Self Assessment', 8, 29],
#  [2015, 'Nonlinear functional mapping of the human brain', 0, 29],
#  [2003,
#   'The first deployment of workload management services on the EU DataGrid Testbed feedback on design and implementation',
#   3,
#   29],
#  [2018,
#   'Learning to Run challenge solutions Adapting reinforcement learning methods for neuromusculoskeletal environments',
#   8,
#   29],
#  [2016,
#   '5G 3GPP-like Channel Models for Outdoor Urban Microcellular and Macrocellular Environments',
#   8,
#   29],
#  [2017,
#   'Prototype Tasks Improving Crowdsourcing Results through Rapid Iterative Task Design',
#   9,
#   29],
#  [2003,
#   'The EU DataGrid Workload Management System towards the second major release',
#   4,
#   29],
#  [2014,
#   'Assessment of algorithms for mitosis detection in breast cancer histopathology images',
#   5,
#   29],
#  [2018,
#   'Code Generation in Computational Neuroscience A Review of Tools and Techniques',
#   5,
#   29],
#  [2014,
#   'Comparing algorithms for automated vessel segmentation in computed tomography scans of the lung the VESSEL12 study',
#   9,
#   29],
#  [2016,
#   'Increasing the impact of medical image computing using community-based open-access hackathons The NA-MIC and 3D Slicer experience',
#   7,
#   29],
#  [2015,
#   'Assessment of algorithms for mitosis detection in breast cancer histopathology images',
#   5,
#   29],
#  [2015,
#   'Right ventricle segmentation from cardiac MRI A collation study',
#   6,
#   29],
#  [2007,
#   'Microarchitecture and implementation of the synergistic processor in 65-nm and 90-nm SOI',
#   3,
#   29],
#  [2013,
#   'A data infrastructure reference model with applications towards realization of a ScienceTube vision with a data replication service',
#   8,
#   29],
#  [2010, 'Report on INEX 2009', 6, 29],
#  [2019,
#   'An Energy-Efficient Graphics Processor in 14-nm Tri-Gate CMOS Featuring Integrated Voltage Regulators for Fine-Grain DVFS Retentive Sleep and $V_textMIN$ Optimization',
#   1,
#   29],
#  [2016, 'A 128 Gb 3bcell V-NAND Flash Memory With 1 Gbs IO Rate', 8, 29],
#  [2017, '256 Gb 3 bCell V-nand Flash Memory With 48 Stacked WL Layers', 6, 29],
#  [2016, 'OSoMe the IUNI observatory on social media', 1, 29],
#  [2014, 'TERAFLUX Harnessing dataflow in next generation teradevices', 6, 29],
#  [2015,
#   'Creating a specialist protein resource network a meeting report for the protein bioinformatics and community resources retreat',
#   9,
#   29],
#  [2014, 'XIA architecting a more trustworthy and evolvable internet', 8, 29],
#  [2009,
#   'Short-term adaptation to a simple motor task A physiological process preserved in multiple sclerosis',
#   7,
#   29],
#  [2008,
#   'Reproducibility of fMRI in the clinical setting Implications for trial designs',
#   3,
#   29],
#  [2015,
#   'Disentangling type 2 diabetes and metformin treatment signatures in the human gut microbiota',
#   1,
#   29],
#  [2016, 'OSoMe The IUNI observatory on social media', 1, 29],
#  [2019,
#   'In-Vivo Hyperspectral Human Brain Image Database for Brain Cancer Detection',
#   1,
#   28],
#  [2005,
#   'A Collaborative Informatics Infrastructure for Multi-Scale Science',
#   2,
#   28],
#  [2010,
#   'A proposal for a standard interface between Monte Carlo tools and one-loop programs',
#   8,
#   28],
#  [2011,
#   'The Translational Medicine Ontology and Knowledge Base driving personalized medicine by bridging the gap between bench and bedside',
#   7,
#   28],
#  [2018,
#   'The New York City Off-Hour Delivery Program A Business and Community-Friendly Sustainability Program',
#   6,
#   28],
#  [2006, 'Intelligent Transportation Systems', 8, 28],
#  [2019,
#   'Intelligent systems for geosciences an essential research agenda',
#   3,
#   28],
#  [2011,
#   'Ground-Based Optical Measurements at European Flux Sites A Review of Methods Instruments and Current Controversies',
#   7,
#   28],
#  [2019,
#   'Conceptual Representations for Computational Concept Creation',
#   0,
#   28],
#  [2011, 'Minimum Information About a Simulation Experiment MIASE', 5, 28],
#  [2009,
#   'The GAAS Metagenomic Tool and Its Estimations of Viral and Microbial Average Genome Size in Four Major Biomes',
#   5,
#   28],
#  [2009, 'Design and implementation of a CMO 80211n SoC', 3, 28],
#  [2000, 'Criteria for Evaluating AAA Protocols for Network Access', 9, 28],
#  [2017,
#   'SMAP L-Band Microwave Radiometer Instrument Design and First Year on Orbit',
#   3,
#   28],
#  [2006,
#   'Early validation analyses of atmospheric profiles from EOS MLS on the aura Satellite',
#   7,
#   28],
#  [2018, 'HMDB 40 the human metabolome database for 2018', 7, 28],
#  [2006, 'Genome Snapshot a new resource at the ', 9, 28],
#  [2018,
#   'VDJdb a curated database of T-cell receptor sequences with known antigen specificity',
#   8,
#   28],
#  [2011, 'RegulonDB version 70 transcriptional regulation of ', 4, 28],
#  [2009,
#   'CDD specific functional annotation with the Conserved Domain Database',
#   8,
#   28],
#  [2017,
#   'Influenza Research Database An integrated bioinformatics resource for influenza virus research',
#   1,
#   28],
#  [2017,
#   'Improvements to PATRIC the all-bacterial Bioinformatics Database and Analysis Resource Center',
#   9,
#   28],
#  [2003, 'MMDB Entrezs 3D-structure database', 8, 28],
#  [2011, 'The RIKEN integrated database of mammals', 8, 28],
#  [2016,
#   'ANISEED 2015 a digital framework for the comparative developmental biology of ascidians',
#   0,
#   28],
#  [2005,
#   'The Rat Genome Database RGD developments towards a phenome database',
#   8,
#   28],
#  [2012, 'GeneDB - an annotation database for pathogens', 8, 28],
#  [2004, 'E-MSD an integrated data resource for bioinformatics', 1, 28],
#  [2003,
#   'ELM server a new resource for investigating short functional sites in modular eukaryotic proteins',
#   3,
#   28],
#  [2001,
#   'The InterPro database an integrated documentation resource for protein families domains and functional sites',
#   0,
#   28],
#  [2009,
#   'GiardiaDB and TrichDB integrated genomic resources for the eukaryotic protist pathogens ',
#   1,
#   28],
#  [2014,
#   'PATRIC the bacterial bioinformatics database and analysis resource',
#   0,
#   28],
#  [2005, 'CandidaDB a genome database for ', 8, 28],
#  [2017,
#   'WALK-MAN A High-Performance Humanoid Platform for Realistic Environments',
#   2,
#   28],
#  [2008, 'A perception-driven autonomous urban vehicle', 5, 28],
#  [2014,
#   'Community-driven development for computational biology at Sprints Hackathons and Codefests',
#   3,
#   28],
#  [2013,
#   'Phylotastic Making tree-of-life knowledge accessible reusable and convenient',
#   8,
#   28],
#  [2011, 'The gene normalization task in BioCreative III', 6, 28],
#  [2011,
#   'U-Compare bio-event meta-service compatible BioNLP event extraction services',
#   3,
#   28],
#  [2016,
# ...
#   7,
#   23],
#  [2011,
#   'Open Data Open Source and Open Standards in chemistry The Blue Obelisk five years on',
#   5,
#   23],
#  [2009, 'Breaking ECC2K-130', 3, 23],
#  [2009,
#   'Janus An FPGA-Based System for High-Performance Scientific Computing',
#   4,
#   23],
#  [2018,
#   'Synthetic Biology Open Language Visual SBOL Visual Version 20',
#   6,
#   23],
#  [2018, 'Synthetic Biology Open Language SBOL Version 220', 8, 23],
#  [2016, 'Synthetic Biology Open Language SBOL Version 210', 8, 23],
#  [2017, 'Development of the MPEG-H TV Audio System for ATSC 30', 8, 23],
#  [2018,
#   'An Intraoperative Visualization System Using Hyperspectral Imaging to Aid in Brain Tumor Delineation',
#   1,
#   23],
#  [2013, 'The AAAI-13 Conference Workshops', 1, 23],
#  [2005, 'Reports on the 2005 AAAI Spring Symposium Series', 5, 23],
#  [2016, 'The development of non-coding RNA ontology', 8, 23],
#  [2017,
#   'Variation in high-priority drug-drug interaction alerts across institutions and electronic health records',
#   7,
#   23],
#  [2006,
#   'Application of Information Technology Design and Implementation of an Application and Associated Services to Support Interdisciplinary Medication Reconciliation Efforts at an Integrated Healthcare Delivery Network',
#   5,
#   23],
#  [2015,
#   'CSER and eMERGE current and potential state of the display of genetic information in the electronic health record',
#   1,
#   23],
#  [2001, 'CDMA2000 Wireless Data Requirements for AAA', 1, 23],
#  [1998,
#   'The Moderate Resolution Imaging Spectroradiometer MODIS land remote sensing for global change research',
#   3,
#   23],
#  [2017,
#   'Surface Soil Moisture Retrieval Using the L-Band Synthetic Aperture Radar Onboard the Soil Moisture Active-Passive Satellite and Evaluation at Core Validation Sites',
#   6,
#   23],
#  [2017,
#   'Naming the pain in requirements engineering - Contemporary problems causes and effects in practice',
#   3,
#   23],
#  [2000, 'The Jalapeño virtual machine', 6, 23],
#  [2011,
#   'COMBREX a project to accelerate the functional annotation of prokaryotic genomes',
#   0,
#   23],
#  [2018, 'The European Nucleotide Archive in 2017', 7, 23],
#  [2004,
#   'Saccharomyces Genome Database SGD provides tools to identify and analyze sequences from Saccharomyces cerevisiae and related sequences from other organisms',
#   8,
#   23],
#  [2013, 'HMDB 30 - The Human Metabolome Database in 2013', 8, 23],
#  [2009, 'RAPID Resource of Asian Primary Immunodeficiency Diseases', 5, 23],
#  [2011,
#   'ZFIN enhancements and updates to the zebrafish model organism database',
#   8,
#   23],
#  [2019,
#   'The PRIDE database and related tools and resources in 2019 improving support for quantification data',
#   8,
#   23],
#  [2009, 'TB database an integrated platform for tuberculosis research', 3, 23],
#  [2011,
#   'ENCODE whole-genome data in the UCSC genome browser 2011 update',
#   9,
#   23],
#  [2016, 'The UCSC Genome Browser database 2016 update', 9, 23],
#  [2014,
#   'EBI metagenomics - a new resource for the analysis and archiving of metagenomic data',
#   8,
#   23],
#  [2010, 'The UCSC Genome Browser database update 2010', 9, 23],
#  [2019,
#   'Database resources of the National Center for Biotechnology Information',
#   1,
#   23],
#  [2014, 'The Reactome pathway knowledgebase', 3, 23],
#  [2010, 'ELM the status of the 2010 eukaryotic linear motif resource', 9, 23],
#  [2018, 'The Reactome Pathway Knowledgebase', 3, 23],
#  [2019,
#   '15 years of GDR New data and functionality in the Genome Database for Rosaceae',
#   9,
#   23],
#  [2017,
#   'CARD 2017 expansion and model-centric curation of the comprehensive antibiotic resistance database',
#   6,
#   23],
#  [2013,
#   'The MCIC Collection A Shared Repository of Multi-Modal Multi-Site Brain Image Data from a Clinical Investigation of Schizophrenia',
#   1,
#   23],
#  [2017,
#   'Team VALORs ESCHER A Novel Electromechanical Biped for the DARPA Robotics Challenge',
#   0,
#   23],
#  [2017,
#   'Team SNUs Control Strategies for Enhancing a Robots Capability Lessons from the 2015 DARPA Robotics Challenge Finals',
#   0,
#   23],
#  [2016,
#   'VDJML a file format with tools for capturing the results of inferring immune receptor rearrangements',
#   9,
#   23],
#  [2007, 'Advancing translational research with the Semantic Web', 7, 23],
#  [2018, 'Adversarial Attacks and Defences Competition', 7, 23],
#  [2018, 'Construction of the Literature Graph in Semantic Scholar', 3, 23],
#  [2018,
#   'Deep learning to achieve clinically applicable segmentation of head and neck anatomy for radiotherapy',
#   8,
#   23],
#  [2007,
#   'SECOQC White Paper on Quantum Key Distribution and Cryptography',
#   2,
#   23],
#  [2017,
#   'Human-level CMR image analysis with deep fully convolutional networks',
#   5,
#   23],
#  [2018, 'fastMRI An Open Dataset and Benchmarks for Accelerated MRI', 5, 23],
#  [2016, 'BioInfoBase  A Bioinformatics Resourceome', 0, 23],
#  [2014, 'AsterixDB A Scalable Open Source BDMS', 5, 23],
#  [2014,
#   'Field and long-term demonstration of a wide area quantum key distribution network',
#   2,
#   23],
#  [2018,
#   'Status Quo in Requirements Engineering A Theory and a Global Family of Surveys',
#   9,
#   23],
#  [2016,
#   'Naming the Pain in Requirements Engineering Contemporary Problems Causes and Effects in Practice',
#   3,
#   23],
#  [2003, 'Adapting SAM for CDF', 8, 23],
#  [2003,
#   'Managing Dynamic User Communities in a Grid of Autonomous Resources',
#   7,
#   23],
#  [2019,
#   'Robotic-assisted Ultrasound for Fetal Imaging Evolution from Single-arm to Dual-arm System',
#   4,
#   23],
#  [2018,
#   'The CAMH Neuroinformatics Platform A Hospital-Focused Brain-CODE Implementation',
#   3,
#   23],
#  [2015, 'IBM POWER8 circuit design and energy optimization', 3, 23],
#  [2005, 'Blue GeneL programming and operating environment', 4, 23],
#  [2003,
#   'Evaluation of annotation strategies using an entire genome sequence',
#   1,
#   23],
#  [2005,
#   'MamMiBase a mitochondrial genome database for mammalian phylogenetic studies',
#   9,
#   23],
#  [2000, 'How Far Does the First Element Dominate 10649', 7, 23],
#  [1992, 'A 200-MHz 64-bit Dual-Issue CMOS Microprocessor', 7, 23],
#  [2015,
#   'Analysis of current validation practices in Europe for space-based climate data records of essential climate variables',
#   3,
#   23],
#  [2013,
#   'ImaGiNe Seldinger First simulator for Seldinger technique and angiography training',
#   2,
#   23],
#  [2009,
#   'ImmunoGrid an integrative environment for large-scale simulation of the immune system for vaccine discovery design and optimization',
#   3,
#   23],
#  [2004,
#   'Saccharomyces genome database Underlying principles and organisation',
#   8,
#   23],
#  [2011,
#   'Computing with bacterial constituents cells and populations from bioputing to bactoputing',
#   3,
#   23],
#  [2010, 'The Soil Moisture Active Passive SMAP Mission', 0, 23],
#  [2018,
#   'The Need of Multidisciplinary Approaches and Engineering Tools for the Development and Implementation of the Smart City Paradigm',
#   8,
#   23],
#  [2013,
#   'From Visible Light-Emitting Diodes to Large-Scale III-V Photonic Integrated Circuits',
#   0,
#   23],
#  [2013,
#   'A survey on resource allocation in high performance distributed computing systems',
#   1,
#   23],
#  [2018,
#   'The 24-Core POWER9 Processor With Adaptive Clocking 25-Gbs Accelerator Links and 16-Gbs PCIe Gen4',
#   1,
#   23],
#  [2010,
#   'A 3 Watt 398-446 Gbs Dual-Mode SFI52 SerDes Chip Set in 65 nm CMOS',
#   0,
#   23],
#  [2018,
#   'A 65-nm CMOS 2×2 MIMO Multi-Band LTE RF Transceiver for Small Cell Base Stations',
#   4,
#   23],
#  [2016, 'SPARC M7 A 20 nm 32-Core 64 MB L3 Cache Processor', 3, 23],
#  [2014,
#   'A 28 Gbs 560 mW Multi-Standard SerDes With Single-Stage Analog Front-End and 14-Tap Decision Feedback Equalizer in 28 nm CMOS',
#   6,
#   23],
#  [2018,
#   'Dual-Loop Two-Step ZQ Calibration for Dynamic Voltage-Frequency Scaling in LPDDR4 SDRAM',
#   5,
#   23],
#  [2014, 'Small molecule annotation for the Protein Data Bank', 1, 23],
#  [2015, 'On Processing Extreme Data', 8, 23],
#  [2014,
#   'Using quantum key distribution for cryptographic purposes A survey',
#   4,
#   23],
#  [1989,
#   'The Perfect Club Benchmarks Effective Performance Evaluation of Supercomputers',
#   9,
#   23],
#  [2014,
#   'The current state-of-the-art of spinal cord imaging Applications',
#   9,
#   23],
#  [2018,
#   'The distribution of the alpha7 nicotinic acetylcholine receptor in healthy aging An in vivo positron emission tomography study with ',
#   9,
#   23],
#  [2014,
#   'Reliability of functional magnetic resonance imaging activation during working memory in a multi-site study Analysis from the North American Prodrome Longitudinal Study',
#   9,
#   23],
#  [2013,
#   'Imaging epigenetic regulation by histone deacetylases in the brain using PETMRI with ',
#   0,
#   23],
#  [2016,
#   'Hierarchical virtualised and distributed intelligence 5G architecture for low-latency and secure applications',
#   8,
#   23],
#  [2005,
#   'Science and technology in the region The output of regional science and technology its strengths and its leading institutions',
#   4,
#   23],
#  [2014, 'AsterixDB A Scalable Open Source BDMS', 5, 23],
#  [2013,
#   'A longitudinal study of state government homepage accessibility in Maryland and the role of web page templates for improving accessibility',
#   7,
#   22],
#  [2009,
#   'GRIDA3 - a shared resources manager for environmental data analysis and applications',
#   1,
#   22],
#  [2003, 'New designs for MRI contrast agents', 9, 22],
#  [2017,
#   'Drug target ontology to classify and integrate drug discovery data',
#   7,
#   22],
#  [2017,
#   'Comparison of Satellite Reflectance Algorithms for Estimating Phycocyanin Values and Cyanobacterial Total Biovolume in a Temperate Reservoir Using Coincident Hyperspectral Aircraft Imagery and Dense Coincident Surface Observations',
#   8,
#   22],
#  [2018,
#   'Modification of Local Urban Aerosol Properties by Long-Range Transport of Biomass Burning Aerosol',
#   5,
#   22],
#  [2010,
#   'Retinopathy Online Challenge Automatic Detection of Microaneurysms in Digital Color Fundus Photographs',
#   5,
#   22],
#  [2014,
#   'Quantitative Comparison of Reconstruction Methods for Intra-Voxel Fiber Recovery From Diffusion MRI',
#   6,
#   22],
#  [2015,
#   'Undergraduate Students Compete in the IEEE Signal Processing Cup Part 2 sp Education',
#   9,
#   22],
#  [2018, 'Embracing First-Person Perspectives in Soma-Based Design', 8, 22],
#  [2015,
#   'Evaluating and comparing language workbenches Existing results and benchmarks for the future',
#   3,
#   22],
#  [2015,
#   'Crop modelling for integrated assessment of risk to food production from climate change',
#   8,
#   22],
#  [2014,
#   'Evolutionary algorithms and other metaheuristics in water resources Current status research challenges and future directions',
#   9,
#   22],
#  [2019,
#   'Combined OCT distance and FBG force sensing cannulation needle for retinal vein cannulation in vivo animal validation',
#   1,
#   22],
#  [2013,
#   'Understanding the mechanisms amenable to CRT response from pre-operative multimodal image data to patient-specific computational models',
#   1,
#   22],
#  [2010, 'Applications in Data-Intensive Computing', 4, 22],
#  [2003,
#   'IMAGINE Interfacing Mobile Application with Voice Natural Language Interactivity',
#   6,
#   22],
#  [2018,
#   'Foil Strain Gauges Using Piezoresistive Carbon Nanotube Yarn Fabrication and Calibration',
#   7,
#   22],
#  [2015,
#   'Computer versus physician identification of gastrointestinal alarm features',
#   9,
#   22],
#  [2017,
#   'Assessment of a personalized and distributed patient guidance system',
#   8,
#   22],
#  [2001, 'AAAI 2000 Workshop Reports', 9, 22],
#  [2006, 'AAAI 2006 Spring Symposium Reports', 5, 22],
#  [2004, 'Project Halo Towards a Digital Aristotle', 0, 22],
#  [2016,
#   'A Crowdsourcing Approach to Developing and Assessing Prediction Algorithms for AML Prognosis',
#   5,
#   22],
#  [2016,
#   'Enhancing LTE with Cloud-RAN and Load-Controlled Parasitic Antenna Arrays',
#   1,
#   22],
#  [2014, 'The Swarm at the Edge of the Cloud', 1, 22],
#  [2017,
#   'On the complexities of utilizing large-scale lightpath-connected distributed cyberinfrastructure',
#   2,
#   22],
#  [2018, 'Open Innovation in the Big Data Era With the MOVING Platform', 8, 22],
#  [2017,
#   'Global land mapping of satellite-observed CO2 total columns using spatio-temporal geostatistics',
#   8,
#   22],
#  [1998,
#   'Clouds and the Earths Radiant Energy System CERES algorithm overview',
#   7,
#   22],
#  [2013,
#   'Canadian Experiment for Soil Moisture in 2010 CanEx-SM10 Overview and Preliminary Results',
#   2,
#   22],
#  [2003, 'The ERGOTM genome analysis and discovery system', 8, 22],
#  [2012,
#   'Saccharomyces Genome Database the genomics resource of budding yeast',
#   8,
#   22],
#  [2008,
#   'The Zebrafish Information Network the zebrafish model organism database provides expanded support for genotypes and phenotypes',
#   5,
#   22],
#  [2018,
#   'Freiburg RNA tools a central online resource for RNA-focused research and teaching',
#   5,
#   22],
#  [2013,
#   'The NIH genetic testing registry a new centralized database of genetic tests to enable access to comprehensive information and improve transparency',
#   1,
#   22],
#  [2018,
#   'Expression Atlas gene and protein expression across multiple studies and organisms',
#   1,
#   22],
#  [2003, 'WormBase a cross-species database for comparative genomics', 8, 22],
#  [2017,
#   'CDDSPARCLE functional classification of proteins via subfamily domain architectures',
#   8,
#   22],
#  [2015, 'The BioGRID interaction database 2015 update', 9, 22],
#  [2005,
#   'The Human Anatomic Gene Expression Library H-ANGEL the H-Inv integrative display of human gene expression across disparate technologies and platforms',
#   1,
#   22],
#  [2015, 'GenoBase comprehensive resource database of ', 8, 22],
#  [2010, '', 0, 22],
#  [2012, 'The IntAct molecular interaction database in 2012', 7, 22],
#  [2018,
#   'WikiPathways a multifaceted pathway database bridging metabolomics to other omics research',
#   8,
#   22],
#  [2018, 'DrugBank 50 a major update to the DrugBank database for 2018', 8, 22],
#  [2018,
#   'PDBe towards reusable data delivery infrastructure at protein data bank in Europe',
#   1,
#   22],
#  [2016, 'The Reactome pathway Knowledgebase', 3, 22],
#  [2005,
#   'The CATH Domain Structure Database and related resources Gene3D and DHS provide comprehensive domain family information for genome analysis',
#   0,
#   22],
#  [2015,
#   'ViRBase a resource for virus-host ncRNA-associated interactions',
#   7,
#   22],
#  [2011,
#   'ArrayExpress update - an archive of microarray and high-throughput sequencing-based functional genomics experiments',
#   8,
#   22],
#  [2012,
#   'Gene Expression Atlas update - a value-added database of microarray and sequencing-based functional genomics experiments',
#   8,
#   22],
#  [2018,
#   'ClinVar improving access to variant interpretations and supporting evidence',
#   9,
#   22],
#  [2011, 'EMDataBankorg unified data resource for CryoEM', 1, 22],
#  [2017,
#   'Protein Ontology PRO enhancing and scaling up the representation of protein entities',
#   9,
#   22],
#  [2000,
#   'MitBASE  a comprehensive and integrated mitochondrial DNA database The present status',
#   9,
#   22],
#  [2009, 'The UCSC Genome Browser Database update 2009', 6, 22],
#  [2011,
#   'Reactome a database of reactions pathways and biological processes',
#   8,
#   22],
#  [2017,
#   'Robot System of DRC-HUBO+ and Control Strategy of Team KAIST in DARPA Robotics Challenge Finals',
#   7,
#   22],
#  [2017,
#   'Team WPI-CMU Achieving Reliable Humanoid Behavior in the DARPA Robotics Challenge',
#   7,
#   22],
#  [2008,
#   'Caroline An autonomously driving vehicle for urban environments',
#   0,
#   22],
#  [2006,
#   'A robust approach to high-speed navigation for unrehearsed desert terrain',
#   8,
#   22],
#  [2015,
#   'An overview of the BIOASQ large-scale biomedical semantic indexing and question answering competition',
#   9,
#   22],
#  [2014,
#   'Caroline An Autonomously Driving Vehicle for Urban Environments',
#   0,
#   22],
#  [2019,
#   'Automated Quality Control in Image Segmentation Application to the UK Biobank Cardiac MR Imaging Study',
#   9,
#   22],
#  [1999, 'Emerging Challenges in Computational Topology', 1, 22],
#  [2017,
#   'The use of neural networks in the analysis of sleep stages and the diagnosis of narcolepsy',
#   1,
#   22],
#  ...]

# %% [markdown]
# ## Save outputs

# %%
lda_model_bow.save('./model/lda_bow.model')

# %%
writer = csv.writer(open("./data/title_topics_authors.csv", "w", encoding="UTF", newline=''))
writer.writerow(['Year','Title','Topic','nAuthors'])
writer.writerows(dashboard_output_format)

# %%
reader = csv.reader(open("./data/title_topics_authors.csv", "r", encoding="UTF", newline=''))
line_count = 0
last_row = -1
for row in reader:
    if line_count < 10 and line_count > 0:
        if int(row[0]) != dashboard_output_format[line_count][0]:
            print("row[0]:", row[0], "\t var:", dashboard_output_format[line_count][0])
    line_count += 1
    last_row = row
print("Lines read:", line_count)
print("Last row:", last_row)
# Out:
# row[0]: 1996 	 var: 1983
# row[0]: 1983 	 var: 1982
# row[0]: 1982 	 var: 1977
# row[0]: 1977 	 var: 2011
# row[0]: 2011 	 var: 1987
# row[0]: 1987 	 var: 1988
# row[0]: 1988 	 var: 1978
# row[0]: 1978 	 var: 2012
# Lines read: 2008468
# Last row: ['1991', 'Object ADTs with improvements for Value ADTs', '6', '3']

# %%
f = open("./data/topic_labels.txt", "w")
f.write("Label\n")
for topic_label in topic_labels:
    f.write(topic_label+"\n")
f.close()

# %%
f = open("./data/topic_labels_unique.txt", "w")
f.write("Label\n")
for topic_label in topic_labels_merged:
    f.write(topic_label+"\n")
f.close()
