# %%
import numpy as np
from numpy import genfromtxt
import pandas as pd

import csv
import json

# %% [markdown]
# ## 1. Word-cloud

# %%
def generate_word_cloud_output_format(term_counts, size=20, save_mode=True):
    # Assumes that term_counts is sorted by count
    output = [[term_count[0], term_count[1]] for term_count in term_counts[:size]]
    if save_mode:
        f = open("./data/wordcloud_output_format.json","w")
        json.dump(output, f)
        f.close()
        
    return output

# %%
f = open("./data/keyword_counts.json","r")
keyword_counts_raw = json.load(f)
f.close()

# %%
# Sort as it is a dict() and order need not have been preserved
keyword_counts = sorted(keyword_counts_raw.items(), key = lambda kv:(kv[1], kv[0]), reverse=True)
keyword_counts[:100]
# Out:
# [('system', 191799),
#  ('network', 166093),
#  ('model', 111842),
#  ('analysis', 101884),
#  ('algorithm', 97362),
#  ('data', 83604),
#  ('method', 81866),
#  ('approach', 73121),
#  ('problem', 66562),
#  ('application', 66391),
#  ('control', 65290),
#  ('learning', 60695),
#  ('design', 60176),
#  ('image', 55137),
#  ('information', 53651),
#  ('dynamic', 45930),
#  ('graph', 45692),
#  ('detection', 42851),
#  ('study', 41767),
#  ('new', 41368),
#  ('performance', 40169),
#  ('optimization', 37933),
#  ('wireless', 36651),
#  ('neural', 36613),
#  ('estimation', 34629),
#  ('adaptive', 34213),
#  ('efficient', 33874),
#  ('fuzzy', 33855),
#  ('sensor', 31748),
#  ('linear', 31313),
#  ('modeling', 31255),
#  ('function', 31018),
#  ('scheme', 29853),
#  ('optimal', 29646),
#  ('mobile', 29518),
#  ('management', 29274),
#  ('distributed', 29161),
#  ('time', 29007),
#  ('communication', 28883),
#  ('channel', 28602),
#  ('process', 28520),
#  ('equation', 27539),
#  ('service', 27432),
#  ('framework', 26778),
#  ('power', 26750),
#  ('classification', 26229),
#  ('evaluation', 26021),
#  ('set', 25379),
#  ('structure', 25337),
#  ('software', 25309),
#  ('technique', 24998),
#  ('simulation', 24690),
#  ('code', 24690),
#  ('multiple', 24504),
#  ('environment', 24432),
#  ('computing', 23788),
#  ('recognition', 23715),
#  ('solution', 22957),
#  ('robust', 22704),
#  ('nonlinear', 22659),
#  ('effect', 22651),
#  ('theory', 22318),
#  ('machine', 22275),
#  ('feature', 22086),
#  ('case', 21207),
#  ('technology', 21194),
#  ('social', 21178),
#  ('parallel', 20838),
#  ('development', 20783),
#  ('architecture', 20696),
#  ('scheduling', 20594),
#  ('selection', 20380),
#  ('hybrid', 20072),
#  ('programming', 19643),
#  ('digital', 19292),
#  ('decision', 19256),
#  ('space', 19080),
#  ('signal', 19005),
#  ('web', 18720),
#  ('search', 18520),
#  ('protocol', 18509),
#  ('novel', 18507),
#  ('prediction', 18353),
#  ('online', 18304),
#  ('logic', 18275),
#  ('knowledge', 18221),
#  ('energy', 18175),
#  ('language', 18119),
#  ('fast', 18103),
#  ('research', 18065),
#  ('video', 18057),
#  ('strategy', 17966),
#  ('computer', 17862),
#  ('pattern', 17681),
#  ('matrix', 17669),
#  ('support', 17666),
#  ('review', 17593),
#  ('stochastic', 17582),
#  ('random', 17105),
#  ('implementation', 17052)]

# %%
generate_word_cloud_output_format(keyword_counts, size=25, save_mode=True)
# Out:
# [['system', 191799],
#  ['network', 166093],
#  ['model', 111842],
#  ['analysis', 101884],
#  ['algorithm', 97362],
#  ['data', 83604],
#  ['method', 81866],
#  ['approach', 73121],
#  ['problem', 66562],
#  ['application', 66391],
#  ['control', 65290],
#  ['learning', 60695],
#  ['design', 60176],
#  ['image', 55137],
#  ['information', 53651],
#  ['dynamic', 45930],
#  ['graph', 45692],
#  ['detection', 42851],
#  ['study', 41767],
#  ['new', 41368],
#  ['performance', 40169],
#  ['optimization', 37933],
#  ['wireless', 36651],
#  ['neural', 36613],
#  ['estimation', 34629]]

# %% [markdown]
# ## 2. Co-occurrence Matrix

# %%
def generate_cooccurrence_matrix_output_format(term_counts, term_topic, term_cooccurrence_matrix, size=20, log_scale=False,
                                               sort_order='count', save_mode=True, savefile_name=None):
    nodes, links = [], []
    
    if sort_order == 'count':
        sorted_terms = sorted(term_counts, key = lambda kv:kv[1])
    elif sort_order == 'name':
        sorted_terms = sorted(term_counts, key = lambda kv:kv[0])
    
    for (term, count) in sorted_terms:
        nodes.append({"name":term, "count":count, "group":term_topic[term]})
        if len(nodes) == size:
            break
    
    for i, row_node_info in enumerate(nodes):
        for j, col_node_info in enumerate(nodes):
            cooccurrence_count = int(term_cooccurrence_matrix.loc[row_node_info["name"], col_node_info["name"]])
            links.append({"source":i, "target":j, 
                          "value": round(np.log(cooccurrence_count), 2) if log_scale else cooccurrence_count})

    output = {"nodes":nodes, "links":links}
    if save_mode:
        f = open(savefile_name,"w")
        json.dump(output, f)
        f.close()
        
    return json.dumps(output)

# %%
f = open("./data/top_keyword_top_topic.json","r")
top_term_top_topic = json.load(f)
f.close()
top_term_top_topic
# Out:
# {'system': 9,
#  'network': 10,
#  'model': 2,
#  'analysis': 2,
#  'algorithm': 6,
#  'data': 1,
#  'method': 6,
#  'approach': 2,
#  'problem': 6,
#  'application': 7,
#  'control': 9,
#  'learning': 2,
#  'design': 7,
#  'image': 8,
#  'information': 12,
#  'dynamic': 9,
#  'graph': 5,
#  'detection': 8,
#  'study': 11,
#  'new': 6,
#  'performance': 3,
#  'optimization': 6,
#  'wireless': 10,
#  'neural': 8,
#  'estimation': 3,
#  'adaptive': 9,
#  'efficient': 0,
#  'fuzzy': 9,
#  'sensor': 10,
#  'linear': 6,
#  'modeling': 2,
#  'function': 5,
#  'scheme': 0,
#  'optimal': 9,
#  'mobile': 10,
#  'management': 1,
#  'distributed': 10,
#  'time': 6,
#  'communication': 10,
#  'channel': 3,
#  'process': 1,
#  'equation': 6,
#  'service': 12,
#  'framework': 1,
#  'power': 10,
#  'classification': 8,
#  'evaluation': 7,
#  'set': 5,
#  'structure': 1,
#  'software': 7,
#  'technique': 4,
#  'simulation': 3,
#  'code': 3,
#  'multiple': 10,
#  'environment': 7,
#  'computing': 0,
#  'recognition': 8,
#  'solution': 6,
#  'robust': 9,
#  'nonlinear': 6,
#  'effect': 3,
#  'theory': 11,
#  'machine': 2,
#  'feature': 8,
#  'case': 11,
#  'technology': 11,
#  'social': 12,
#  'parallel': 0,
#  'development': 7,
#  'architecture': 0,
#  'scheduling': 0,
#  'selection': 8,
#  'hybrid': 9,
#  'programming': 6,
#  'digital': 7,
#  'decision': 9,
#  'space': 5,
#  'signal': 4,
#  'web': 12,
#  'search': 5,
#  'protocol': 10,
#  'novel': 8,
#  'prediction': 2,
#  'online': 12,
#  'logic': 9,
#  'knowledge': 1,
#  'energy': 10,
#  'language': 11,
#  'fast': 8,
#  'research': 11,
#  'video': 12,
#  'strategy': 10,
#  'computer': 11,
#  'pattern': 2,
#  'matrix': 5,
#  'support': 9,
#  'review': 7,
#  'stochastic': 6,
#  'random': 5,
#  'implementation': 0}

# %%
term_cooccurrence_matrix = pd.read_csv("./data/term_cooccurrence_matrix.csv", index_col=0)

# %%
term_cooccurrence_matrix
# Out:
#                 system  network  model  analysis  algorithm  data  method  \
# system            3717     7639   8918     11606       6256  5962    6327
# network           7639     4050   8339     10373       9344  7429    3653
# model             8918     8339   1740      6362       3483  5616    3313
# analysis         11606    10373   6362       853       4365  8615    5359
# algorithm         6256     9344   3483      4365        765  3888    2032
# data              5962     7429   5616      8615       3888  2833    3717
# method            6327     3653   3313      5359       2032  3717     824
# approach          8270     6834   3598      4075       1662  4230    1123
# problem           2660     3027   1924      2039      10158   888    6722
# application       7208     4820   4392      4288       3554  3532    3514
# control          19215     7751   4597      2405       2314  1239    2198
# learning          4118     5255   3844      1663       3056  2849    1872
# design           12121     5505   2532      4292       2551  1282    1910
# image             1951     2748   3009      3409       3569  1665    3561
# information      11386     3321   2962      2203        814  2005    1329
# dynamic           6297     6412   4517      2682       2458  1724    1596
# graph              861     1505   1077       835       2730   665     518
# detection         4821     4854   1942      2179       2666  2248    2447
# study             3977     2515   2382      2172       1298  1975    1705
# new               3717     2609   2589      1846       3991  1500    4714
# performance       6643     5500   2073      7682       2089  1467    1185
# optimization      3320     4119   2107      1550       6551   946    3008
# wireless          3714    26033    987      1731       2602  2291     637
# neural            3026    28781   3164      1883       1705  1124    1060
# estimation        4358     2367   3070      1299       2538  1939    2267
# adaptive          6743     4085   1854      1189       3593  1120    1914
# efficient         2615     4679   1490       950       5197  2220    2334
# fuzzy             6882     2666   3078      1815       2303  1430    2414
# sensor            2370    18474    890      1096       2419  2985     918
# linear            7694     1490   2610      1783       2476   637    2475
# ...                ...      ...    ...       ...        ...   ...     ...
# scheduling        2479     2681    821       602       3467   667     438
# selection         1696     2510   2249      1073       2047  1299    1506
# hybrid            3881     2620   1802       961       2918   787    1633
# programming       1281      816   1321       532       1473   404    1183
# digital           1712      583    887       813        608   652     561
# decision          3598      909   1634      1246        823   771    1077
# space             1135      711    854       757        738   496     840
# signal            1485     1026    715      1646       1065   417    1118
# web               1054      486    856       928        327  1256     299
# search             861      868    691       528       3106   714     960
# protocol           972     5582    454      1317        252   629     214
# novel             2232     2075   1316       998       2500   920    2493
# prediction        1237     2696   2444       798        951  1251    1129
# online            1219     1711    897       851        856   713     397
# logic             1485      597    815       435        420   194     321
# knowledge         2214      947    979       698        212   862     393
# energy            2803     4026    886       965        842   865     618
# language          1421      459   1327       528        196   537     246
# fast              1016     1149    696       592       3776   696    1669
# research          2121      976    700      1080        405  1298     619
# video             1178     1827    667       848        825   448     498
# strategy          1776     1913    823       765        611   765     374
# computer          2126     1138    797       828        519   398     480
# pattern           1024     1229    870      1345        845  1060     672
# matrix             951      569    489       751       1575   489    1275
# support           4405     1175    989       784        570   976     556
# review            1499      668    631       756        374   657     572
# stochastic        3123     2065   2463      1291       1146   290    1252
# random             889     1838   1468       800        764   531     605
# implementation    2830     1126    912       862       1495   507     730
#
#                 approach  problem  application       ...        video  \
# system              8270     2660         7208       ...         1178
# network             6834     3027         4820       ...         1827
# model               3598     1924         4392       ...          667
# analysis            4075     2039         4288       ...          848
# algorithm           1662    10158         3554       ...          825
# data                4230      888         3532       ...          448
# method              1123     6722         3514       ...          498
# approach              96     3882         2055       ...          531
# problem             3882      769         2552       ...           29
# application         2055     2552          197       ...          677
# control             3145     2297         2797       ...          481
# learning            3397      960         1765       ...          689
# design              3203     1199         2865       ...          333
# image               2306      236         2331       ...          815
# information         2204      599         1455       ...          255
# dynamic             2250     1446         1518       ...          389
# graph                894     1937          930       ...           65
# detection           2321      222         1620       ...         1195
# study               1180      804         1449       ...          270
# new                 4189     2110         1844       ...          288
# performance         1167      383         1404       ...          337
# optimization        2437     4840         1756       ...          261
# wireless            1248      314         1278       ...          914
# neural              1661      662         1471       ...          198
# estimation          1539      440         1326       ...          531
# adaptive            1385      696         1235       ...          789
# efficient           1388     1227          964       ...          610
# fuzzy               3178     1535         2438       ...           94
# sensor              1105      316         1374       ...          193
# linear              1314     2644          982       ...           45
# ...                  ...      ...          ...       ...          ...
# scheduling          1157     3134          662       ...          153
# selection           1439      709          665       ...          202
# hybrid              2001     1458          802       ...          209
# programming         1828     2727          880       ...           24
# digital              573       95          600       ...          418
# decision            1351      980         1123       ...          154
# space                502      817          688       ...           63
# signal               696      115         1004       ...          154
# web                  983       78         1525       ...          139
# search               704     2176          474       ...          169
# protocol             273      117          483       ...           98
# novel               2597      456          957       ...          267
# prediction          1062      140          778       ...          383
# online               602      292          390       ...          299
# logic                630      218          552       ...           22
# knowledge            923      208          446       ...           46
# energy               709      192          679       ...          104
# language             496      260          435       ...           83
# fast                 490      454          563       ...          411
# research             496      209          699       ...           66
# video                531       29          677       ...          523
# strategy             424      597          450       ...          130
# computer             413      346          758       ...           68
# pattern              791      257          713       ...          100
# matrix               636      727          850       ...           29
# support              732      251          738       ...           88
# review               505      254          802       ...          104
# stochastic          1053     1449          672       ...           28
# random               428      525          550       ...           56
# implementation       383      272          692       ...          163
#
#                 strategy  computer  pattern  matrix  support  review  \
# system              1776      2126     1024     951     4405    1499
# network             1913      1138     1229     569     1175     668
# model                823       797      870     489      989     631
# analysis             765       828     1345     751      784     756
# algorithm            611       519      845    1575      570     374
# data                 765       398     1060     489      976     657
# method               374       480      672    1275      556     572
# approach             424       413      791     636      732     505
# problem              597       346      257     727      251     254
# application          450       758      713     850      738     802
# control             1482       342      235     264      304     325
# learning             803       697      754     263      929     593
# design               599       847      781     373      888     467
# image                245       351      669     328      338     256
# information          671       393      349     191      711    1196
# dynamic              634       217      416     173      259     155
# graph                 81        65      300     442       54      60
# detection            236       221      587     205      400     292
# study                548       588      445     117      534     432
# new                  544       396      361     450      298     436
# performance          538       461      206     158      269     185
# optimization         768       132      180     275      300     180
# wireless             510        38       84      60      258     194
# neural               181       109      635     191      235     156
# estimation           164        79      173     607      170     109
# adaptive             585        83      238     220      280      54
# efficient            447       124      415     384      261      33
# fuzzy                237        52      344     297      462     173
# sensor               397        36      159      78      162     229
# linear               160        74      135     763      139      43
# ...                  ...       ...      ...     ...      ...     ...
# scheduling           354        65       31      35      153      84
# selection            516        67      177     106      445     104
# hybrid               416        89      127      81      231      51
# programming          173       308      103     134      186     183
# digital              166       306      103      43      163     385
# decision             249       121      109      73     4065     203
# space                124        63      129     157      114      42
# signal                75        68      162     174      125     118
# web                  155        70      256      26      213     282
# search               531       111      303      57      113      83
# protocol              69        64       20      18      166     107
# novel                385        61      248     142      200      29
# prediction           141        63      183     114      426     102
# online               309        85      198      60      350     617
# logic                 89       125       70      35       56     120
# knowledge            286       113      164      27      474     298
# energy               367        57       49      42       76      83
# language              88       267      254      68      193     184
# fast                 116        97      202     484      117      14
# research             230       405      133      23      301     870
# video                130        68      100      29       88     104
# strategy              91       118      117     108      144     147
# computer             118       301      117      74      215     407
# pattern              117       117      215     101      194      91
# matrix               108        74      101     391       44      30
# support              144       215      194      44      119     182
# review               147       407       91      30      182     254
# stochastic           213        47       76     178       33      63
# random                95        46      147     474       72      42
# implementation       232       197       75     108      177     108
#
#                 stochastic  random  implementation
# system                3123     889            2830
# network               2065    1838            1126
# model                 2463    1468             912
# analysis              1291     800             862
# algorithm             1146     764            1495
# data                   290     531             507
# method                1252     605             730
# approach              1053     428             383
# problem               1449     525             272
# application            672     550             692
# control               1810     326             642
# learning               483     341             292
# design                 356     188            3062
# image                  136     564             336
# information            264     183             441
# dynamic                894     255             281
# graph                  125    1790              68
# detection              208     413             205
# study                  135     131             552
# new                    256     201             353
# performance            290     281             518
# optimization          1145     256             205
# wireless               175     358             309
# neural                 724     243             375
# estimation             507     495             162
# adaptive               527     219             319
# efficient              213     272            1034
# fuzzy                  369     459             231
# sensor                 151     263             258
# linear                 723     516             178
# ...                    ...     ...             ...
# scheduling             314     111              82
# selection              142     238              82
# hybrid                 280     102             168
# programming            780     112             201
# digital                 36      55             380
# decision               181     105             128
# space                  119     136              95
# signal                 192     277             177
# web                     20      20             142
# search                 243     262             101
# protocol                38     122             319
# novel                  102     111             184
# prediction             116     192              54
# online                 123      81              77
# logic                   56      52             200
# knowledge                9      23             164
# energy                 183      98              99
# language                92      47             303
# fast                   111     165             346
# research                21      17             168
# video                   28      56             163
# strategy               213      95             232
# computer                47      46             197
# pattern                 76     147              75
# matrix                 178     474             108
# support                 33      72             177
# review                  63      42             108
# stochastic             250     356              53
# random                 356     263              59
# implementation          53      59              29
#
# [100 rows x 100 columns]

# %%
generate_cooccurrence_matrix_output_format(keyword_counts[:25], top_term_top_topic, term_cooccurrence_matrix,
                                           size=25, log_scale=True, sort_order='name',
                                           save_mode=True, savefile_name="./data/cooccurrence_matrix_log_output_format.json")
# Out:
# '{"nodes": [{"name": "algorithm", "count": 97362, "group": 6}, {"name": "analysis", "count": 101884, "group": 2}, {"name": "application", "count": 66391, "group": 7}, {"name": "approach", "count": 73121, "group": 2}, {"name": "control", "count": 65290, "group": 9}, {"name": "data", "count": 83604, "group": 1}, {"name": "design", "count": 60176, "group": 7}, {"name": "detection", "count": 42851, "group": 8}, {"name": "dynamic", "count": 45930, "group": 9}, {"name": "estimation", "count": 34629, "group": 3}, {"name": "graph", "count": 45692, "group": 5}, {"name": "image", "count": 55137, "group": 8}, {"name": "information", "count": 53651, "group": 12}, {"name": "learning", "count": 60695, "group": 2}, {"name": "method", "count": 81866, "group": 6}, {"name": "model", "count": 111842, "group": 2}, {"name": "network", "count": 166093, "group": 10}, {"name": "neural", "count": 36613, "group": 8}, {"name": "new", "count": 41368, "group": 6}, {"name": "optimization", "count": 37933, "group": 6}, {"name": "performance", "count": 40169, "group": 3}, {"name": "problem", "count": 66562, "group": 6}, {"name": "study", "count": 41767, "group": 11}, {"name": "system", "count": 191799, "group": 9}, {"name": "wireless", "count": 36651, "group": 10}], "links": [{"source": 0, "target": 0, "value": 6.64}, {"source": 0, "target": 1, "value": 8.38}, {"source": 0, "target": 2, "value": 8.18}, {"source": 0, "target": 3, "value": 7.42}, {"source": 0, "target": 4, "value": 7.75}, {"source": 0, "target": 5, "value": 8.27}, {"source": 0, "target": 6, "value": 7.84}, {"source": 0, "target": 7, "value": 7.89}, {"source": 0, "target": 8, "value": 7.81}, {"source": 0, "target": 9, "value": 7.84}, {"source": 0, "target": 10, "value": 7.91}, {"source": 0, "target": 11, "value": 8.18}, {"source": 0, "target": 12, "value": 6.7}, {"source": 0, "target": 13, "value": 8.02}, {"source": 0, "target": 14, "value": 7.62}, {"source": 0, "target": 15, "value": 8.16}, {"source": 0, "target": 16, "value": 9.14}, {"source": 0, "target": 17, "value": 7.44}, {"source": 0, "target": 18, "value": 8.29}, {"source": 0, "target": 19, "value": 8.79}, {"source": 0, "target": 20, "value": 7.64}, {"source": 0, "target": 21, "value": 9.23}, {"source": 0, "target": 22, "value": 7.17}, {"source": 0, "target": 23, "value": 8.74}, {"source": 0, "target": 24, "value": 7.86}, {"source": 1, "target": 0, "value": 8.38}, {"source": 1, "target": 1, "value": 6.75}, {"source": 1, "target": 2, "value": 8.36}, {"source": 1, "target": 3, "value": 8.31}, {"source": 1, "target": 4, "value": 7.79}, {"source": 1, "target": 5, "value": 9.06}, {"source": 1, "target": 6, "value": 8.36}, {"source": 1, "target": 7, "value": 7.69}, {"source": 1, "target": 8, "value": 7.89}, {"source": 1, "target": 9, "value": 7.17}, {"source": 1, "target": 10, "value": 6.73}, {"source": 1, "target": 11, "value": 8.13}, {"source": 1, "target": 12, "value": 7.7}, {"source": 1, "target": 13, "value": 7.42}, {"source": 1, "target": 14, "value": 8.59}, {"source": 1, "target": 15, "value": 8.76}, {"source": 1, "target": 16, "value": 9.25}, {"source": 1, "target": 17, "value": 7.54}, {"source": 1, "target": 18, "value": 7.52}, {"source": 1, "target": 19, "value": 7.35}, {"source": 1, "target": 20, "value": 8.95}, {"source": 1, "target": 21, "value": 7.62}, {"source": 1, "target": 22, "value": 7.68}, {"source": 1, "target": 23, "value": 9.36}, {"source": 1, "target": 24, "value": 7.46}, {"source": 2, "target": 0, "value": 8.18}, {"source": 2, "target": 1, "value": 8.36}, {"source": 2, "target": 2, "value": 5.28}, {"source": 2, "target": 3, "value": 7.63}, {"source": 2, "target": 4, "value": 7.94}, {"source": 2, "target": 5, "value": 8.17}, {"source": 2, "target": 6, "value": 7.96}, {"source": 2, "target": 7, "value": 7.39}, {"source": 2, "target": 8, "value": 7.33}, {"source": 2, "target": 9, "value": 7.19}, {"source": 2, "target": 10, "value": 6.84}, {"source": 2, "target": 11, "value": 7.75}, {"source": 2, "target": 12, "value": 7. ...
